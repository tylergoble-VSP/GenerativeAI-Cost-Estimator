# %% [markdown]
# # Notebook 02: Inference and Question Generation
#
# This notebook demonstrates:
# 1. Loading embedded chunks from the previous notebook
# 2. Asking user-defined questions about the document
# 3. Auto-generating questions from chunks
# 4. Tracking tokens and timing for all inference calls
# 5. Saving inference metrics for reporting
#
# ## Setup

# %%
# Import standard library modules
import json
import sys
from pathlib import Path

# Add the src directory to Python path
project_root = Path().resolve().parent
sys.path.insert(0, str(project_root))

# Import our custom modules
from src.config import Config
from src.pipeline import generate_questions, save_metrics
from src.ollama_client import generate
from src.timing_metrics import MetricsStore, TimingContext
from src.token_accounting import count_tokens, count_prompt_and_response

print("Modules imported successfully!")
# Out:
# Modules imported successfully!

# %% [markdown]
# ## Configuration and Load Previous Results

# %%
# Create configuration (same as notebook 01)
config = Config(
    embedding_model="embeddinggemma",
    generation_model="gemma3:1b",
    ollama_endpoint="http://localhost:11434"
)

# Load embedded chunks from previous notebook
chunks_path = config.get_chunks_path()
print(f"Loading chunks from: {chunks_path}")

with open(chunks_path, 'r') as f:
    embedded_chunks = json.load(f)

print(f"Loaded {len(embedded_chunks)} embedded chunks")

# Create metrics store for inference metrics
# We'll add to this as we make inference calls
inference_metrics_store = MetricsStore()
# Out:
# Loading chunks from: results/chunks.json
# Loaded 772 embedded chunks

# %% [markdown]
# ## User-Defined Questions
#
# Ask your own questions about the document. Each question will be sent to the model with relevant context from the chunks.

# %%
# Example user-defined questions
# You can modify these or add your own
user_questions = [
    "What is the main theme of this passage?",
    "What question does this passage make you ask yourself?",
    "What is the main charater of this passage?"
]

# Store all question-answer pairs
qa_pairs = []

# Process each user question
for idx, question in enumerate(user_questions):
    print(f"\n{'='*60}")
    print(f"Question {idx + 1}: {question}")
    print('='*60)
    
    # For simplicity, we'll use the first chunk as context
    # In a real RAG system, you'd use vector similarity to find the most relevant chunks
    context_chunk = embedded_chunks[0] if embedded_chunks else None
    
    if context_chunk:
        # Build prompt with context
        prompt = f"""Based on the following text, answer this question: {question}

Text:
{context_chunk['text']}

Answer:"""
        
        # Count prompt tokens
        prompt_tokens = count_tokens(prompt)
        
        # Time the inference call
        with TimingContext() as timer:
            # Call Ollama to generate answer
            response_text, metadata = generate(
                prompt,
                config.generation_model,
                config.ollama_endpoint
            )
        
        # Get duration
        duration = timer.duration
        
        # Count response tokens
        response_tokens = count_tokens(response_text)
        
        # Record metrics
        question_id = f"user_question_{idx}"
        inference_metrics_store.add_inference_metric(
            duration=duration,
            prompt_tokens=prompt_tokens,
            response_tokens=response_tokens,
            question_id=question_id,
            response_text=response_text
        )
        
        # Store Q&A pair
        qa_pairs.append({
            'question_id': question_id,
            'question': question,
            'answer': response_text,
            'chunk_id': context_chunk['chunk_id']
        })
        
        # Display results
        print(f"\nAnswer:")
        print(response_text)
        print(f"\nMetrics:")
        print(f"  Prompt tokens: {prompt_tokens}")
        print(f"  Response tokens: {response_tokens}")
        print(f"  Total tokens: {prompt_tokens + response_tokens}")
        print(f"  Duration: {duration:.2f} seconds")
        print(f"  Tokens/second: {(prompt_tokens + response_tokens) / duration:.2f}" if duration > 0 else "  Tokens/second: N/A")
    else:
        print("No chunks available for context")
# Out:
# ============================================================
# Question 1: What is the main theme of this passage?
# ============================================================
#
# Answer:
# The main theme of this passage is the exploration of obsession and the destructive nature of unchecked ambition, particularly as exemplified by Captain Ahab’s pursuit of Moby Dick. It’s a story about a man consumed by a desire for revenge and the dangerous consequences of pursuing a singular, almost mythical, goal. The text also hints at themes of fate, the unknowable, and the vastness of the natural world, all woven together through the narrative of a whale.
#
# Metrics:
#   Prompt tokens: 534
#   Response tokens: 93
#   Total tokens: 627
#   Duration: 2.48 seconds
#   Tokens/second: 252.59
#
# ============================================================
# Question 2: What question does this passage make you ask yourself?
# ============================================================
#
# Answer:
# What question does this passage make you ask yourself?
#
# The passage primarily invites self-reflection on the story’s themes and the author’s intent. It asks, “What does this text suggest about the nature of obsession, the power of storytelling, and the potential consequences of pursuing a singular vision?” It also subtly prompts a consideration of the narrative’s structure and its exploration of a complex, somewhat unsettling, world.
#
# Metrics:
#   Prompt tokens: 535
#   Response tokens: 81
#   Total tokens: 616
#   Duration: 2.03 seconds
#   Tokens/second: 302.73
#
# ============================================================
# Question 3: What is the main charater of this passage?
# ============================================================
#
# Answer:
# Based on the text, the main character of this passage is **Herman Melville**. The text directly states he is the author of the ebook and that it is a retelling of Moby Dick.
#
#
# Metrics:
#   Prompt tokens: 535
#   Response tokens: 42
#   Total tokens: 577
#   Duration: 1.25 seconds
#   Tokens/second: 461.45

# %% [markdown]
# ## Auto-Generate Questions from Chunks
#
# Automatically generate questions from chunks. This is useful for creating a question-answer dataset or testing the system.

# %%
# Generate questions from a few sample chunks
# This demonstrates the auto-generation capability
num_chunks_to_process = max(3, len(embedded_chunks))  # Process first 3 chunks
questions_per_chunk = 2  # Generate 2 questions per chunk

print(f"Generating {questions_per_chunk} questions from {num_chunks_to_process} chunks...")
print("This may take a while.\n")

all_generated_questions = []

for i, chunk in enumerate(embedded_chunks[:num_chunks_to_process]):
    print(f"\n{'='*60}")
    print(f"Processing chunk {i+1}/{num_chunks_to_process}: {chunk['chunk_id']}")
    print('='*60)
    
    # Generate questions for this chunk
    questions = generate_questions(
        chunk,
        num_questions=questions_per_chunk,
        config=config,
        metrics_store=inference_metrics_store
    )
    
    all_generated_questions.extend(questions)
    
    # Display generated questions
    for q in questions:
        print(f"\nQuestion: {q['question_text']}")

print(f"\n\nTotal questions generated: {len(all_generated_questions)}")
# Out:
# Generating 2 questions from 772 chunks...
# This may take a while.
#
#
# ============================================================
# Processing chunk 1/772: chunk_0
# ============================================================
#
# Question: What is the cost and restrictions of accessing the ebook?
#
# Question: What is the release date of the ebook?
#
# ============================================================
# Processing chunk 2/772: chunk_1
# ============================================================
#
# Question: What does Stubb do to Ahab?
#
# Question: What is the significance of “To Him, Stubb” in the text?
#
# ============================================================
# Processing chunk 3/772: chunk_2
# ============================================================
#
# Question: What is the primary focus of the text’s chapters 75-89?
#
# ============================================================
# Processing chunk 4/772: chunk_3
# ============================================================
#
# Question: What is the text about?
#
# Question: What does the text imply about the original Usher?
#
# ============================================================
# Processing chunk 5/772: chunk_4
# ============================================================
#
# Question: What is the definition of “WHALE” as described in the text?
#
# Question: What does the text suggest about the importance of the extracts?
#
# ============================================================
# Processing chunk 6/772: chunk_5
# ============================================================
#
# Question: What is the main point of the text?
#
# Question: What does the text state about Leviathan?
#
# ============================================================
# Processing chunk 7/772: chunk_6
# ============================================================
#
# Question: What is the primary focus of Isaiah’s punishment?
#
# Question: What is the significance of the “whale’s” bones for the king?
#
# ============================================================
# Processing chunk 8/772: chunk_7
# ============================================================
#
# Question: What is the sea-gudgeon doing in the whale’s mouth?
#
# Question: What is the significance of the whale’s liver?
#
# ============================================================
# Processing chunk 9/772: chunk_8
# ============================================================
#
# Question: What is the focus of the text?
#
# Question: What is the significance of the “pikes” on the Leviathan’s back?
#
# ============================================================
# Processing chunk 10/772: chunk_9
# ============================================================
#
# Question: What specific actions were the explorers causing that nature placed on their shoulders?
#
# Question: What was the significance of the whale found near Shetland?
#
# ============================================================
# Processing chunk 11/772: chunk_10
# ============================================================
#
# Question: What is Richard Strafford’s primary motivation for attempting to master and kill the sperm whale?
#
# Question: According to the text, how does the whale’s ferocity and swiftness affect the reader?
#
# ============================================================
# Processing chunk 12/772: chunk_11
# ============================================================
#
# Question: What was discovered in the afternoon, and why was it significant?
#
# Question: What did the sailors do to attempt to conceal themselves from the whale?
#
# ============================================================
# Processing chunk 13/772: chunk_12
# ============================================================
#
# Question: What is the primary focus of the text regarding the crews’ repair?
#
# Question: What does the text imply about the whale’s size compared to other objects?
#
# ============================================================
# Processing chunk 14/772: chunk_13
# ============================================================
#
# Question: What is the primary subject of the text?
#
# Question: What specific detail about whaling is highlighted in Montgomery’s World?
#
# ============================================================
# Processing chunk 15/772: chunk_14
# ============================================================
#
# Question: What is Cooper’s Pilot referring to as “that fellow”？
#
# Question: What is the main focus of the text regarding the sperm whale?
#
# ============================================================
# Processing chunk 16/772: chunk_15
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: According to the text, what is the Cachalot’s distinguishing feature compared to the True Whale?
#
# ============================================================
# Processing chunk 17/772: chunk_16
# ============================================================
#
# Question: What island was the Nantucket Globe located on?
#
# Question: What was Mr. Webster’s primary concern regarding Nantucket?
#
# ============================================================
# Processing chunk 18/772: chunk_17
# ============================================================
#
# Question: What is the central theme of the text?
#
# Question: What specific detail about the whale is emphasized in the passage?
#
# ============================================================
# Processing chunk 19/772: chunk_18
# ============================================================
#
# Question: What is Ishmael’s primary reason for traveling about the world?
#
# Question: What is the purpose of Ishmael’s activity described in the text?
#
# ============================================================
# Processing chunk 20/772: chunk_19
# ============================================================
#
# Question: What is Cato’s substitute for a pistol and ball?
#
# Question: What is the significance of the “green fields” mentioned in the text?
#
# ============================================================
# Processing chunk 21/772: chunk_20
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: What is the artist’s goal in creating the landscape?
#
# ============================================================
# Processing chunk 22/772: chunk_21
# ============================================================
#
# Question: What is the primary theme of the text?
#
# Question: What is the significance of the “mystical vibration” experienced by the poet?
#
# ============================================================
# Processing chunk 23/772: chunk_22
# ============================================================
#
# Question: What does the speaker mean by “a passenger”?
#
# Question: What is the speaker’s primary concern when considering sea travel?
#
# ============================================================
# Processing chunk 24/772: chunk_23
# ============================================================
#
# Question: What specific aspect of being a schoolmaster does the text emphasize as unpleasant?
#
# Question: What does the text suggest about the relationship between sailors and passengers?
#
# ============================================================
# Processing chunk 25/772: chunk_24
# ============================================================
#
# Question: What is the text’s central argument about money?
#
# Question: What is the significance of the whaling voyage in the context of the text?
#
# ============================================================
# Processing chunk 26/772: chunk_25
# ============================================================
#
# Question: What was the primary motivation for the whaling voyage as described in the text?
#
# Question: What does the text suggest about the narrator’s character?
#
# ============================================================
# Processing chunk 27/772: chunk_26
# ============================================================
#
# Question: What is the setting of the text?
#
# Question: What is the narrator’s initial plan?
#
# ============================================================
# Processing chunk 28/772: chunk_27
# ============================================================
#
# Question: What was the primary purpose of the sloop’s voyage?
#
# Question: What did Ishmael bring with him to New Bedford?
#
# ============================================================
# Processing chunk 29/772: chunk_28
# ============================================================
#
# Question: What was the initial goal of the narrator?
#
# Question: What was the significance of the “Spouter Inn?”
#
# ============================================================
# Processing chunk 30/772: chunk_29
# ============================================================
#
# Question: What is the initial feeling the narrator experiences upon seeing the sign?
#
# Question: What does the narrator conclude about the significance of the name “Coffin”?
#
# ============================================================
# Processing chunk 31/772: chunk_30
# ============================================================
#
# Question: What does the old writer believe the eyes of the narrator are?
#
# Question: What is Lazarus’s apparent preference for his surroundings?
#
# ============================================================
# Processing chunk 32/772: chunk_31
# ============================================================
#
# Question: What is the primary goal of the group in this text?
#
# Question: What is the description of the Spouter-Inn like?
#
# ============================================================
# Processing chunk 33/772: chunk_32
# ============================================================
#
# Question: What was the initial effect of the painting on the narrator?
#
# Question: What specific elements in the painting contribute to its unsettling atmosphere?
#
# ============================================================
# Processing chunk 34/772: chunk_33
# ============================================================
#
# Question: What type of weapons were originally stored in the ‘storyd weapons’?
#
# Question: What was the significance of the ‘restless needle’ traveling through the whale’s body?
#
# ============================================================
# Processing chunk 35/772: chunk_34
# ============================================================
#
# Question: What is the primary subject of the text?
#
# Question: What is the landlord’s reaction to the narrator’s request for a room?
#
# ============================================================
# Processing chunk 36/772: chunk_35
# ============================================================
#
# Question: What was the weather like at the meal?
#
# Question: What did the landlord fear the harpooneer would do?
#
# ============================================================
# Processing chunk 37/772: chunk_36
# ============================================================
#
# Question: What type of sea boots were heard in the entry?
#
# Question: What was the man’s primary occupation?
#
# ============================================================
# Processing chunk 38/772: chunk_37
# ============================================================
#
# Question: What was the man’s facial feature that was strikingly contrasted by the lighting?
#
# Question: What was the man’s apparent profession, based on the text?
#
# ============================================================
# Processing chunk 39/772: chunk_38
# ============================================================
#
# Question: What was the initial impression of the harpooneer?
#
# Question: What did the harpooneer do after the landlord left?
#
# ============================================================
# Processing chunk 40/772: chunk_39
# ============================================================
#
# Question: What was the width of the first bench compared to the other bench?
#
# Question: What caused the draft of cold air?
#
# ============================================================
# Processing chunk 41/772: chunk_40
# ============================================================
#
# Question: What is the landlord’s initial reaction to the story being told?
#
# Question: What does the landlord intend to do with the harpooneer?
#
# ============================================================
# Processing chunk 42/772: chunk_41
# ============================================================
#
# Question: What is the specific discomfort the narrator feels toward the harpooneer?
#
# Question: What potential legal consequence does the landlord threaten?
#
# ============================================================
# Processing chunk 43/772: chunk_42
# ============================================================
#
# Question: What is the landlord’s primary concern regarding the harpooneer?
#
# Question: What detail does the text suggest about the harpooneer’s behavior?
#
# ============================================================
# Processing chunk 44/772: chunk_43
# ============================================================
#
# Question: What did Sal offer to lead the way?
#
# Question: What did the landlord do when he disappeared?
#
# ============================================================
# Processing chunk 45/772: chunk_44
# ============================================================
#
# Question: What did the narrator do with the door mat?
#
# Question: What was the narrator’s initial reaction to the door mat?
#
# ============================================================
# Processing chunk 46/772: chunk_45
# ============================================================
#
# Question: What is the Lord’s primary concern at the beginning of the passage?
#
# Question: What does the harpooneer’s face resemble?
#
# ============================================================
# Processing chunk 47/772: chunk_46
# ============================================================
#
# Question: What is the stranger’s skin color described as?
#
# Question: What did the stranger do with the New Zealand head?
#
# ============================================================
# Processing chunk 48/772: chunk_47
# ============================================================
#
# Question: What caused the narrator’s fear of the man?
#
# Question: What did the man appear to be in a Thirty Years’ War?
#
# ============================================================
# Processing chunk 49/772: chunk_48
# ============================================================
#
# Question: What is the setting of the text?
#
# Question: What is the significance of the image the savage sets up?
#
# ============================================================
# Processing chunk 50/772: chunk_49
# ============================================================
#
# Question: What was the initial reaction of the narrator to the cannibal’s actions?
#
# Question: What significant event occurs in the text that leads to the narrator’s sudden realization of the cannibal’s identity?
#
# ============================================================
# Processing chunk 51/772: chunk_50
# ============================================================
#
# Question: What is Queequeg’s primary motivation for being concerned about the landlord’s smoking?
#
# Question: How does the description of the counterpane contribute to the atmosphere of the story?
#
# ============================================================
# Processing chunk 52/772: chunk_51
# ============================================================
#
# Question: What was the setting of the previous paragraph?
#
# Question: What was the central sensation experienced by the narrator?
#
# ============================================================
# Processing chunk 53/772: chunk_52
# ============================================================
#
# Question: What caused the small person to ache?
#
# Question: What happened to the person after falling into a nightmare?
#
# ============================================================
# Processing chunk 54/772: chunk_53
# ============================================================
#
# Question: What was the initial feeling the narrator experienced while seeing the supernatural hand?
#
# Question: What action did the narrator attempt to take to awaken the man?
#
# ============================================================
# Processing chunk 55/772: chunk_54
# ============================================================
#
# Question: What caused the narrator to succeed in extracting a grunt from Queequeg?
#
# Question: What did Queequeg do after the narrator understood he would dress him?
#
# ============================================================
# Processing chunk 56/772: chunk_55
# ============================================================
#
# Question: What was Queequeg’s profession?
#
# Question: What was the significance of the “small degree civilized” aspect of Queequeg?
#
# ============================================================
# Processing chunk 57/772: chunk_56
# ============================================================
#
# Question: What did Queequeg do with his razor?
#
# Question: What did Queequeg do with the harpoon?
#
# ============================================================
# Processing chunk 58/772: chunk_57
# ============================================================
#
# Question: What is the main point of the text?
#
# Question: What details are described about the man’s cheek?
#
# ============================================================
# Processing chunk 59/772: chunk_58
# ============================================================
#
# Question: What does the text suggest might not be the best mode of attaining a high social polish?
#
# Question: Describe the peculiar behavior of the sea-dogs in the text.
#
# ============================================================
# Processing chunk 60/772: chunk_59
# ============================================================
#
# Question: What is the significance of “coolly done” in the text?
#
# Question: What is the overall tone of the text?
#
# ============================================================
# Processing chunk 61/772: chunk_60
# ============================================================
#
# Question: What is the primary motivation of the men arriving in the town?
#
# Question: What is the description of the “country-bred dandy” that appears in the text?
#
# ============================================================
# Processing chunk 62/772: chunk_61
# ============================================================
#
# Question: What is the primary reason the author describes the town of New Bedford as “dearest place to live in” in New England?
#
# Question: According to the text, what does Herr Alexander perform in New Bedford?
#
# ============================================================
# Processing chunk 63/772: chunk_62
# ============================================================
#
# Question: What does the narrator observe about the young girls’ scent?
#
# Question: What does the narrator do when entering the chapel?
#
# ============================================================
# Processing chunk 64/772: chunk_63
# ============================================================
#
# Question: What was the name of the ship towed out of sight?
#
# Question: Who was killed by the sperm whale?
#
# ============================================================
# Processing chunk 65/772: chunk_64
# ============================================================
#
# Question: What is the central theme of the text?
#
# Question: What does the text suggest about the nature of death and eternity?
#
# ============================================================
# Processing chunk 66/772: chunk_65
# ============================================================
#
# Question: What is the central theme of the text?
#
# Question: How does the text characterize Father Mapple?
#
# ============================================================
# Processing chunk 67/772: chunk_66
# ============================================================
#
# Question: What was the weather like when the narrator first observed the man?
#
# Question: What was the purpose of the perpendicular side ladder?
#
# ============================================================
# Processing chunk 68/772: chunk_67
# ============================================================
#
# Question: What does the text suggest about Father Mapple’s motivations?
#
# Question: How does the imagery of the isle of sunlight relate to the text’s themes?
#
# ============================================================
# Processing chunk 69/772: chunk_68
# ============================================================
#
# Question: What is the significance of the “ship’s bluff bows” on the pulpit?
#
# Question: What does the preacher’s prayer seem to convey?
#
# ============================================================
# Processing chunk 70/772: chunk_69
# ============================================================
#
# Question: What is the tone of the text?
#
# Question: What is the significance of the hymn?
#
# ============================================================
# Processing chunk 71/772: chunk_70
# ============================================================
#
# Question: What is the core lesson of Jonah’s story?
#
# Question: What does Jonah’s disobedience to God signify?
#
# ============================================================
# Processing chunk 72/772: chunk_71
# ============================================================
#
# Question: What is the context of the text?
#
# Question: What does Jonah’s appearance suggest?
#
# ============================================================
# Processing chunk 73/772: chunk_72
# ============================================================
#
# Question: What is the primary concern discussed between Jack and Joe?
#
# Question: What action does Jonah take in response to the Captain’s question?
#
# ============================================================
# Processing chunk 74/772: chunk_73
# ============================================================
#
# Question: What does the captain charge Jonah for?
#
# Question: What is Jonah’s state-room?
#
# ============================================================
# Processing chunk 75/772: chunk_74
# ============================================================
#
# Question: What is the primary feeling Jonah experiences?
#
# Question: What is the significance of the lamp’s oscillation?
#
# ============================================================
# Processing chunk 76/772: chunk_75
# ============================================================
#
# Question: What was the first of recorded smugglers?
#
# Question: What does the text suggest Jonah is experiencing?
#
# ============================================================
# Processing chunk 77/772: chunk_76
# ============================================================
#
# Question: What is the main reason for Jonah’s distress?
#
# Question: What is the significance of the lot being cast upon Jonah?
#
# ============================================================
# Processing chunk 78/772: chunk_77
# ============================================================
#
# Question: What was Jonah’s initial state before the merciful turn of the shipmates?
#
# Question: What lesson does the text convey about repentance?
#
# ============================================================
# Processing chunk 79/772: chunk_78
# ============================================================
#
# Question: What does the preacher’s description of the storm reflect?
#
# Question: What is the significance of the preacher’s fleeing from his duty?
#
# ============================================================
# Processing chunk 80/772: chunk_79
# ============================================================
#
# Question: What was Jonah’s original mission?
#
# Question: Where did Jonah flee from?
#
# ============================================================
# Processing chunk 81/772: chunk_80
# ============================================================
#
# Question: What is the primary source of woe mentioned in the text?
#
# Question: What is the main theme of the passage?
#
# ============================================================
# Processing chunk 82/772: chunk_81
# ============================================================
#
# Question: What does the speaker imply about man’s existence?
#
# Question: How does the narrator describe Queequeg’s behavior?
#
# ============================================================
# Processing chunk 83/772: chunk_82
# ============================================================
#
# Question: What did the Pagan’s head appear to be?
#
# Question: What did the text suggest about Queequeg’s character?
#
# ============================================================
# Processing chunk 84/772: chunk_83
# ============================================================
#
# Question: What was the man’s initial reaction to being stranded in Cape Horn?
#
# Question: What does the text suggest about the man’s character?
#
# ============================================================
# Processing chunk 85/772: chunk_84
# ============================================================
#
# Question: What did the little boy notice initially?
#
# Question: What did the narrator do to engage the boy’s interest?
#
# ============================================================
# Processing chunk 86/772: chunk_85
# ============================================================
#
# Question: What was the initial action the narrator took?
#
# Question: What is the central conflict presented in the text?
#
# ============================================================
# Processing chunk 87/772: chunk_86
# ============================================================
#
# Question: What is the main subject of the text?
#
# Question: What is the significance of the description of the couple’s posture?
#
# ============================================================
# Processing chunk 88/772: chunk_87
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: What is the significance of the “blue hanging tester of smoke”?
#
# ============================================================
# Processing chunk 89/772: chunk_88
# ============================================================
#
# Question: What was the geographic location of Rokovoko?
#
# Question: What was Queequeg’s primary motivation for wanting to see more of Christendom?
#
# ============================================================
# Processing chunk 90/772: chunk_89
# ============================================================
#
# Question: What was Queequeg doing when the ship passed through the strait?
#
# Question: What did Queequeg do when the ship passed through the strait?
#
# ============================================================
# Processing chunk 91/772: chunk_90
# ============================================================
#
# Question: What was the initial situation of Queequeg after arriving in Nantucket?
#
# Question: What was the primary reason for Queequeg’s decision to return to the islands?
#
# ============================================================
# Processing chunk 92/772: chunk_91
# ============================================================
#
# Question: What is the reason the narrator felt affection for Queequeg?
#
# Question: What did the narrator do after the story ended?
#
# ============================================================
# Processing chunk 93/772: chunk_92
# ============================================================
#
# Question: What is Queequeg’s preference regarding his harpoon?
#
# Question: What does the story about the wheelbarrow illustrate about Queequeg?
#
# ============================================================
# Processing chunk 94/772: chunk_93
# ============================================================
#
# Question: What was the Captain’s assigned role at the wedding?
#
# Question: What did Queequeg copy while looking upwards?
#
# ============================================================
# Processing chunk 95/772: chunk_94
# ============================================================
#
# Question: What is the central theme of the text?
#
# Question: How does the text describe the atmosphere surrounding the voyages?
#
# ============================================================
# Processing chunk 96/772: chunk_95
# ============================================================
#
# Question: What was the “intense greenness” of the boobies and bumpkins described as?
#
# Question: What did Queequeg do after he caught the bumpkin?
#
# ============================================================
# Processing chunk 97/772: chunk_96
# ============================================================
#
# Question: What was the cause of the boom’s rapid movement?
#
# Question: What did Queequeg do with the boom?
#
# ============================================================
# Processing chunk 98/772: chunk_97
# ============================================================
#
# Question: What does Queequeg ask for?
#
# Question: What does Queequeg say to himself?
#
# ============================================================
# Processing chunk 99/772: chunk_98
# ============================================================
#
# Question: What is the primary reason the Nantucketers embarked on the sea?
#
# Question: What is the significance of the “empty ivory casket” discovered on the island?
#
# ============================================================
# Processing chunk 100/772: chunk_99
# ============================================================
#
# Question: What was the primary focus of the Nantucketer’s exploration?
#
# Question: How did the Nantucketer’s activities impact the global trade?
#
# ============================================================
# Processing chunk 101/772: chunk_100
# ============================================================
#
# Question: What does the narrator’s home represent?
#
# Question: What does Queequeg do in the evening?
#
# ============================================================
# Processing chunk 102/772: chunk_101
# ============================================================
#
# Question: What is the initial reaction of the narrator to the directions given by the captain?
#
# Question: What does the narrator observe in the scene that leads him to feel a vague misgiving?
#
# ============================================================
# Processing chunk 103/772: chunk_102
# ============================================================
#
# Question: What did Mrs. Hussey say when she heard I was thinking about making a clam?
#
# Question: What did the chowder consist of, according to the text?
#
# ============================================================
# Processing chunk 104/772: chunk_103
# ============================================================
#
# Question: What prompted Queequeg to attempt a “little experiment”?
#
# Question: What is the significance of the clam-shells on the area before the house?
#
# ============================================================
# Processing chunk 105/772: chunk_104
# ============================================================
#
# Question: What was the Lady’s demand to Ishmael?
#
# Question: Why does Queequeg refuse the harpoon?
#
# ============================================================
# Processing chunk 106/772: chunk_105
# ============================================================
#
# Question: What is Ishmael’s primary concern regarding Queequeg’s plan?
#
# Question: What is Ishmael’s reaction to Queequeg’s plan?
#
# ============================================================
# Processing chunk 107/772: chunk_106
# ============================================================
#
# Question: What was the initial reaction of the narrator to Queequeg’s behavior?
#
# Question: What did the narrator learn about the ships after his initial explorations?
#
# ============================================================
# Processing chunk 108/772: chunk_107
# ============================================================
#
# Question: What was the appearance of the old ship’s hull?
#
# Question: What was the role of the tiller in the ship?
#
# ============================================================
# Processing chunk 109/772: chunk_108
# ============================================================
#
# Question: What is the significance of the “terrible” shape of the wigwam?
#
# Question: What details are included in the description of the wigwam’s construction?
#
# ============================================================
# Processing chunk 110/772: chunk_109
# ============================================================
#
# Question: What is the description of the old man’s chair made of?
#
# Question: What does the eye-wrinkles on the man’s face signify?
#
# ============================================================
# Processing chunk 111/772: chunk_110
# ============================================================
#
# Question: What is the seaman’s initial suspicion about the man’s motives?
#
# Question: What does the seaman emphasize about the man’s character?
#
# ============================================================
# Processing chunk 112/772: chunk_111
# ============================================================
#
# Question: What was the other leg of Captain Ahab missing?
#
# Question: What is the tone of the text?
#
# ============================================================
# Processing chunk 113/772: chunk_112
# ============================================================
#
# Question: What was the Captain’s initial reaction to the request for the voyage?
#
# Question: What did the Captain state about the weather bow?
#
# ============================================================
# Processing chunk 114/772: chunk_113
# ============================================================
#
# Question: What is the primary characteristic of the Nantucketers described in the text?
#
# Question: What is the significance of the Quaker tradition in the region?
#
# ============================================================
# Processing chunk 115/772: chunk_114
# ============================================================
#
# Question: What is the central theme of the text?
#
# Question: How does the text portray Captain Bildad?
#
# ============================================================
# Processing chunk 116/772: chunk_115
# ============================================================
#
# Question: What was Bildad’s profession before he retired?
#
# Question: What did the crew of the Categut say about Bildad’s behavior?
#
# ============================================================
# Processing chunk 117/772: chunk_116
# ============================================================
#
# Question: What was Bildad’s primary character trait as described in the text?
#
# Question: What did Bildad appear to be doing when he was reading?
#
# ============================================================
# Processing chunk 118/772: chunk_117
# ============================================================
#
# Question: What was Bildad doing while Peleg was talking?
#
# Question: What did Bildad make a point of doing regarding the voyage?
#
# ============================================================
# Processing chunk 119/772: chunk_118
# ============================================================
#
# Question: What was the initial expectation of the 275th lay?
#
# Question: What did Bildad’s behavior suggest about his intentions?
#
# ============================================================
# Processing chunk 120/772: chunk_119
# ============================================================
#
# Question: What is Bildad’s primary reaction to Peleg’s request?
#
# Question: What does Bildad’s response suggest about the significance of the seven hundred and seventy-seventh?
#
# ============================================================
# Processing chunk 121/772: chunk_120
# ============================================================
#
# Question: What does Bildad believe the seven hundred and seventy-seventh lay refers to?
#
# Question: What is Peleg’s reaction to Bildad’s warning?
#
# ============================================================
# Processing chunk 122/772: chunk_121
# ============================================================
#
# Question: What is Bildad’s primary concern regarding the ship’s ownership?
#
# Question: What does Bildad’s reaction to Peleg’s outburst indicate?
#
# ============================================================
# Processing chunk 123/772: chunk_122
# ============================================================
#
# Question: What is Bildad’s primary concern regarding the captain?
#
# Question: What does Peleg ultimately do after the papers are signed?
#
# ============================================================
# Processing chunk 124/772: chunk_123
# ============================================================
#
# Question: What is the primary reason the narrator suggests the young man won’t always see Ahab?
#
# Question: According to the text, what is Ahab’s unique skill or characteristic that sets him apart from other men?
#
# ============================================================
# Processing chunk 125/772: chunk_124
# ============================================================
#
# Question: What caused Captain Ahab’s “moody—desperate moody” state?
#
# Question: What is the tone of the text regarding Ahab?
#
# ============================================================
# Processing chunk 126/772: chunk_125
# ============================================================
#
# Question: What does the narrator feel about Ahab?
#
# Question: How does the narrator react to Queequeg’s Ramadan?
#
# ============================================================
# Processing chunk 127/772: chunk_126
# ============================================================
#
# Question: Why did I allow him to have so much time?
#
# Question: What did I see through the key-hole?
#
# ============================================================
# Processing chunk 128/772: chunk_127
# ============================================================
#
# Question: What is the main reason the man is rushing up the stairs?
#
# Question: What does Mrs. Hussey do to further complicate the situation?
#
# ============================================================
# Processing chunk 129/772: chunk_128
# ============================================================
#
# Question: What does the speaker do when they are running up to the person?
#
# Question: What is the significance of the landlady’s reaction to Queequeg?
#
# ============================================================
# Processing chunk 130/772: chunk_129
# ============================================================
#
# Question: What is the speaker’s primary concern regarding Queequeg?
#
# Question: What is the tone of the text?
#
# ============================================================
# Processing chunk 131/772: chunk_130
# ============================================================
#
# Question: What is the primary reason the narrator is distressed?
#
# Question: What does the narrator do when the narrator’s distress increases?
#
# ============================================================
# Processing chunk 132/772: chunk_131
# ============================================================
#
# Question: What is the author’s concern about a man’s religion becoming frantic?
#
# Question: What is the author’s purpose in arguing with Queequeg?
#
# ============================================================
# Processing chunk 133/772: chunk_132
# ============================================================
#
# Question: What was the cause of the great feast?
#
# Question: What did Queequeg do with the slain?
#
# ============================================================
# Processing chunk 134/772: chunk_133
# ============================================================
#
# Question: What specific type of breakfast did Queequeg have?
#
# Question: What did Captain Peleg demand from Queequeg?
#
# ============================================================
# Processing chunk 135/772: chunk_134
# ============================================================
#
# Question: How long has Philistine been a member of Deacon Deuteronomy’s meeting?
#
# Question: What church does Bildad mean when he asks “What church dost thee mean?”
#
# ============================================================
# Processing chunk 136/772: chunk_135
# ============================================================
#
# Question: What was the harpoon described as?
#
# Question: What did Queequeg do after striking the tar spot?
#
# ============================================================
# Processing chunk 137/772: chunk_136
# ============================================================
#
# Question: What does Queequeg do when Captain Peleg asks him to sign?
#
# Question: What does Queequeg do when Captain Peleg asks him to copy the mark?
#
# ============================================================
# Processing chunk 138/772: chunk_137
# ============================================================
#
# Question: What was the reason for Peleg’s fear of death?
#
# Question: What was Bildad’s immediate reaction to Peleg’s behavior?
#
# ============================================================
# Processing chunk 139/772: chunk_138
# ============================================================
#
# Question: What was Captain Ahab primarily concerned with?
#
# Question: What detail about the stranger’s appearance does Bildad notice?
#
# ============================================================
# Processing chunk 140/772: chunk_139
# ============================================================
#
# Question: What is the stranger’s nervous emphasis on the word “he” suggesting?
#
# Question: What details does the text provide about Captain Ahab’s past?
#
# ============================================================
# Processing chunk 141/772: chunk_140
# ============================================================
#
# Question: What specific details does the beggar-like stranger mention about Captain Ahab’s loss of a leg?
#
# Question: What is the primary tone of the passage regarding the stranger’s statement?
#
# ============================================================
# Processing chunk 142/772: chunk_141
# ============================================================
#
# Question: What was the tone of the speaker throughout the text?
#
# Question: What was the initial impression of Elijah after the encounter?
#
# ============================================================
# Processing chunk 143/772: chunk_142
# ============================================================
#
# Question: What was the immediate reaction of the narrator to the sight of the stranger?
#
# Question: What was the primary reason for the activity aboard the Pequod after Queequeg’s signing of the articles?
#
# ============================================================
# Processing chunk 144/772: chunk_143
# ============================================================
#
# Question: What was the primary concern regarding the ship’s cargo?
#
# Question: What was the main reason for the prolonged absence of the Pequod?
#
# ============================================================
# Processing chunk 145/772: chunk_144
# ============================================================
#
# Question: What was the primary reason for the continuous fetching and carrying on board the Pequod?
#
# Question: What was Captain Charity’s nickname, and what did it signify?
#
# ============================================================
# Processing chunk 146/772: chunk_145
# ============================================================
#
# Question: What did Peleg and Bildad primarily focus on during the preparation for the voyage?
#
# Question: What was the narrator’s initial reaction to the prospect of being committed to the voyage?
#
# ============================================================
# Processing chunk 147/772: chunk_146
# ============================================================
#
# Question: What was the primary reason the sailors were running ahead?
#
# Question: How did Elijah’s actions affect the situation?
#
# ============================================================
# Processing chunk 148/772: chunk_147
# ============================================================
#
# Question: What is the primary sense of urgency conveyed in the text?
#
# Question: What specific detail about the sleeper’s appearance does Elijah point out?
#
# ============================================================
# Processing chunk 149/772: chunk_148
# ============================================================
#
# Question: What is the primary purpose of Queequeg’s actions while narrating the story?
#
# Question: What does Queequeg use the tomahawk-pipe for when he receives the hatchet-side?
#
# ============================================================
# Processing chunk 150/772: chunk_149
# ============================================================
#
# Question: What caused the strong vapor to “tell upon him”?
#
# Question: What did the Captain say to Peleg?
#
# ============================================================
# Processing chunk 151/772: chunk_150
# ============================================================
#
# Question: What was the primary reason for Captain Bildad’s instructions to Captain Peleg?
#
# Question: What was the purpose of the whalebone marquee?
#
# ============================================================
# Processing chunk 152/772: chunk_151
# ============================================================
#
# Question: What was the next command given by the captain?
#
# Question: What was Bildad’s suspected role in the port?
#
# ============================================================
# Processing chunk 153/772: chunk_152
# ============================================================
#
# Question: What does “spring, thou sheep-head” mean?
#
# Question: What does Bildad’s psalmody consist of?
#
# ============================================================
# Processing chunk 154/772: chunk_153
# ============================================================
#
# Question: What was the main reason for the two pilots no longer needing an offing?
#
# Question: How did Peleg and Bildad react to the situation of departing?
#
# ============================================================
# Processing chunk 155/772: chunk_154
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: What is the main sentiment expressed towards Captain Ahab?
#
# ============================================================
# Processing chunk 156/772: chunk_155
# ============================================================
#
# Question: What is the significance of the “shivering winter’s night” described in the text?
#
# Question: What is Bulkington’s apparent state of mind regarding the Pequod?
#
# ============================================================
# Processing chunk 157/772: chunk_156
# ============================================================
#
# Question: What is the central theme of the passage?
#
# Question: What is the significance of the “S.W.F.” initials in relation to whaling?
#
# ============================================================
# Processing chunk 158/772: chunk_157
# ============================================================
#
# Question: What is the primary reason the text attributes to the world’s decline in honoring whaling?
#
# Question: What is the effect of the text regarding the perceived uncleanliness of whaling?
#
# ============================================================
# Processing chunk 159/772: chunk_158
# ============================================================
#
# Question: Why did the Dutch have admirals of whaling fleets in De Witt’s time?
#
# Question: Why did Louis XVI. fit out whaling ships from Dunkirk?
#
# ============================================================
# Processing chunk 160/772: chunk_159
# ============================================================
#
# Question: What was the primary purpose of the American and European men-of-war?
#
# Question: What significant event triggered the shift in trade between Europe and the Pacific?
#
# ============================================================
# Processing chunk 161/772: chunk_160
# ============================================================
#
# Question: What is the whale-ship’s role in the colony’s survival?
#
# Question: Who is credited with writing the first account of whaling, according to the text?
#
# ============================================================
# Processing chunk 162/772: chunk_161
# ============================================================
#
# Question: What is the primary argument against whaling?
#
# Question: What does the text suggest about the whale’s significance?
#
# ...
# Processing chunk 219/772: chunk_218
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: How does the whaling life described impact the character’s experience?
#
# ============================================================
# Processing chunk 220/772: chunk_219
# ============================================================
#
# Question: What is the basic comfort level described in the text?
#
# Question: What is the significance of the mast-heads?
#
# ============================================================
# Processing chunk 221/772: chunk_220
# ============================================================
#
# Question: What is the Sleet’s crow’s-nest intended to do?
#
# Question: What is the purpose of the leather rack in the crow’s-nest?
#
# ============================================================
# Processing chunk 222/772: chunk_221
# ============================================================
#
# Question: What was Captain Sleet’s primary reason for carrying a rifle and powder flask in the crow’s-nest?
#
# Question: What was the “local attraction” of binnacle magnets, according to the text, and what was its potential cause?
#
# ============================================================
# Processing chunk 223/772: chunk_222
# ============================================================
#
# Question: What is the primary reason the speaker is feeling sorry for themselves?
#
# Question: What specific warning does the speaker give to ship owners?
#
# ============================================================
# Processing chunk 224/772: chunk_223
# ============================================================
#
# Question: What is the primary focus of the whale-fishery as described in the text?
#
# Question: What is the harpooneer’s observation about the young man’s lack of interest in the voyage?
#
# ============================================================
# Processing chunk 225/772: chunk_224
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: What does Ahab’s action signify in the context of the passage?
#
# ============================================================
# Processing chunk 226/772: chunk_225
# ============================================================
#
# Question: What was Ahab’s pace like?
#
# Question: What was the significance of the “chick that’s in him” as described by Stubb?
#
# ============================================================
# Processing chunk 227/772: chunk_226
# ============================================================
#
# Question: What does Ahab’s demeanor suggest about his mood?
#
# Question: What is the purpose of the men’s response to Ahab’s question?
#
# ============================================================
# Processing chunk 228/772: chunk_227
# ============================================================
#
# Question: What was Ahab doing with the gold coin?
#
# Question: What did Tashtego, Daggoo, and Queequeg observe about Ahab’s actions?
#
# ============================================================
# Processing chunk 229/772: chunk_228
# ============================================================
#
# Question: What does the Gay-Header say about the white whale?
#
# Question: What is the description of the white whale’s spout?
#
# ============================================================
# Processing chunk 230/772: chunk_229
# ============================================================
#
# Question: What was the primary reason for Ahab’s distress?
#
# Question: What did Starbuck do when Ahab spoke of Moby Dick?
#
# ============================================================
# Processing chunk 231/772: chunk_230
# ============================================================
#
# Question: What is the primary reason Captain Ahab is not hunting whales?
#
# Question: What does Stubb believe the white whale is?
#
# ============================================================
# Processing chunk 232/772: chunk_231
# ============================================================
#
# Question: What is the central conflict Starbuck is facing?
#
# Question: What does Starbuck mean by “Speak, but speak!”?
#
# ============================================================
# Processing chunk 233/772: chunk_232
# ============================================================
#
# Question: What does Ahab do after inhaling Starbuck?
#
# Question: What does Ahab order the harpooneers to do?
#
# ============================================================
# Processing chunk 234/772: chunk_233
# ============================================================
#
# Question: What is the tone of the text?
#
# Question: What does Ahab seem to be focusing on?
#
# ============================================================
# Processing chunk 235/772: chunk_234
# ============================================================
#
# Question: What is the purpose of the harpooneers’ task?
#
# Question: What is the significance of the “goblet end”?
#
# ============================================================
# Processing chunk 236/772: chunk_235
# ============================================================
#
# Question: What is Ahab’s primary concern in the text?
#
# Question: What is the significance of the “iron crown” mentioned in the passage?
#
# ============================================================
# Processing chunk 237/772: chunk_236
# ============================================================
#
# Question: What is the primary conflict driving the speaker’s actions in the text?
#
# Question: What does the speaker believe is happening to him, and what is he attempting to do in response?
#
# ============================================================
# Processing chunk 238/772: chunk_237
# ============================================================
#
# Question: What is the speaker’s primary goal?
#
# Question: What does the speaker feel is “like lead”?
#
# ============================================================
# Processing chunk 239/772: chunk_238
# ============================================================
#
# Question: What is the significance of the “ha, ha’s” in the text?
#
# Question: What does Stubb perceive as the final consequence of his thinking?
#
# ============================================================
# Processing chunk 240/772: chunk_239
# ============================================================
#
# Question: What is the primary purpose of the “chorus” mentioned in the text?
#
# Question: What does the Dutch sailor specifically request from the watch?
#
# ============================================================
# Processing chunk 241/772: chunk_240
# ============================================================
#
# Question: What is the primary purpose of the repeated phrase “tell ’em to avast dreaming of their lasses?”
#
# Question: What is the setting for the scene described in the text?
#
# ============================================================
# Processing chunk 242/772: chunk_241
# ============================================================
#
# Question: What activity is the sailors engaging in while dancing?
#
# Question: What is the Old Man Sailor’s stated intention regarding the scene?
#
# ============================================================
# Processing chunk 243/772: chunk_242
# ============================================================
#
# Question: What imagery is used to describe the waves?
#
# Question: What is the Sailor’s reaction to the imagery of the waves?
#
# ============================================================
# Processing chunk 244/772: chunk_243
# ============================================================
#
# Question: What is the primary threat described in the text?
#
# Question: What is the significance of the “lurid-like, all else pitch black” sky?
#
# ============================================================
# Processing chunk 245/772: chunk_244
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: What is the tone established in the text?
#
# ============================================================
# Processing chunk 246/772: chunk_245
# ============================================================
#
# Question: What is Ahab’s primary motivation for pursuing Moby Dick?
#
# Question: What is the primary reason for the small number of people who have directly confronted Moby Dick?
#
# ============================================================
# Processing chunk 247/772: chunk_246
# ============================================================
#
# Question: What was the nature of the Sperm Whale encountered?
#
# Question: What was the primary reason for the disastrous encounters between Ahab and the whale?
#
# ============================================================
# Processing chunk 248/772: chunk_247
# ============================================================
#
# Question: What is the primary reason for the abundance of rumors in maritime life?
#
# Question: How does the distance of a whaleman’s voyages influence the spread of rumors?
#
# ============================================================
# Processing chunk 249/772: chunk_248
# ============================================================
#
# Question: What was the original prestige of the Sperm Whale?
#
# Question: What is the primary reason for the revivals of superstitious beliefs about the Sperm Whale?
#
# ============================================================
# Processing chunk 250/772: chunk_249
# ============================================================
#
# Question: What is the Baron’s primary feeling about the Sperm Whale?
#
# Question: What is the significance of the “unearthly conceit” regarding Moby Dick?
#
# ============================================================
# Processing chunk 251/772: chunk_250
# ============================================================
#
# Question: What is the central concept the text explores?
#
# Question: What evidence supports the belief that the Nor’ West Passage was never a problem for whales?
#
# ============================================================
# Processing chunk 252/772: chunk_251
# ============================================================
#
# Question: What was the setting for the original stories of the prodigies?
#
# Question: What was the significance of the white forehead and hump on the whale?
#
# ============================================================
# Processing chunk 253/772: chunk_252
# ============================================================
#
# Question: What was the White Whale’s distinctive appellation, according to the text?
#
# ============================================================
# Processing chunk 254/772: chunk_253
# ============================================================
#
# Question: What was Ahab’s motivation for confronting the whale?
#
# ============================================================
# Processing chunk 255/772: chunk_254
# ============================================================
#
# Question: What caused Ahab’s rage?
#
# Question: What did Ahab do immediately after his bodily dismemberment?
#
# ============================================================
# Processing chunk 256/772: chunk_255
# ============================================================
#
# Question: What does the text suggest about Ahab’s mental state?
#
# Question: What is the significance of the “broad madness” as described in the text?
#
# ============================================================
# Processing chunk 257/772: chunk_256
# ============================================================
#
# Question: What is the setting of the text?
#
# Question: What is the significance of Ahab’s “dissembling”?
#
# ============================================================
# Processing chunk 258/772: chunk_257
# ============================================================
#
# Question: What was Ahab’s primary goal for the voyage?
#
# Question: How did Ahab’s crew represent his character?
#
# ============================================================
# Processing chunk 259/772: chunk_258
# ============================================================
#
# Question: What was the primary motivation of Ahab’s pursuit of the White Whale?
#
# Question: What is the vague and mysterious horror described in the text?
#
# ============================================================
# Processing chunk 260/772: chunk_259
# ============================================================
#
# Question: What specific aspect of the whale’s whiteness caused the author distress?
#
# Question: What is the author’s primary concern regarding the “vague, nameless horror”?
#
# ============================================================
# Processing chunk 261/772: chunk_260
# ============================================================
#
# Question: What is the primary focus of the text’s initial unsettling impression?
#
# Question: Which of the listed examples of whiteness is cited as significant in the text’s context?
#
# ============================================================
# Processing chunk 262/772: chunk_261
# ============================================================
#
# Question: What is the primary reason for the widespread recognition of whiteness as a royal preeminence across various nations?
#
# Question: According to the text, what is the significance of the white charger on the Hanoverian flag?
#
# ============================================================
# Processing chunk 263/772: chunk_262
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: What is the effect of the whiteness on the reader?
#
# ============================================================
# Processing chunk 264/772: chunk_263
# ============================================================
#
# Question: What is the significance of the white shark’s “white gliding ghostliness”?
#
# Question: What does the French call the white shark?
#
# ============================================================
# Processing chunk 265/772: chunk_264
# ============================================================
#
# Question: What is the name of the bird described in the text?
#
# Question: What does the text suggest about the bird’s origin?
#
# ============================================================
# Processing chunk 266/772: chunk_265
# ============================================================
#
# Question: What is the White Steed’s primary attribute?
#
# Question: What is the source of the Albino man’s perceived horror?
#
# ============================================================
# Processing chunk 267/772: chunk_266
# ============================================================
#
# Question: What is the primary focus of the text’s argument?
#
# Question: What is the significance of the “marble pallor” in the text?
#
# ============================================================
# Processing chunk 268/772: chunk_267
# ============================================================
#
# Question: What is the significance of the “peculiar apparition to the soul” in the context of whiteness?
#
# Question: What is the purpose of analyzing the “sorcery” described in the passage?
#
# ============================================================
# Processing chunk 269/772: chunk_268
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: What is the significance of the “white veil” in Lima?
#
# ============================================================
# Processing chunk 270/772: chunk_269
# ============================================================
#
# Question: What is the mariner’s primary fear in the example described?
#
# Question: What does the snow-howdahed Andes convey to the native Indian?
#
# ============================================================
# Processing chunk 271/772: chunk_270
# ============================================================
#
# Question: Why does the colt start snorting?
#
# Question: What does the colt smell that evokes the memory of past perils?
#
# ============================================================
# Processing chunk 272/772: chunk_271
# ============================================================

# %% [markdown]
# ## Save Inference Metrics
#
# Save all inference metrics to disk so they can be used in the reporting notebook.

# %%
# Load existing metrics from notebook 01 (if they exist)
# Then merge with inference metrics
import json

metrics_path = config.get_metrics_path()
all_metrics = []

# Load existing metrics
if metrics_path.exists():
    with open(metrics_path, 'r') as f:
        all_metrics = json.load(f)
    print(f"Loaded {len(all_metrics)} existing metrics from notebook 01")

# Add inference metrics
inference_metrics = inference_metrics_store.metrics
all_metrics.extend(inference_metrics)
print(f"Added {len(inference_metrics)} inference metrics")

# Save combined metrics
print(f"\nSaving all metrics to: {metrics_path}")
with open(metrics_path, 'w') as f:
    json.dump(all_metrics, f, indent=2)

print("✅ All metrics saved successfully!")
print("You can now proceed to notebook 03 for reporting and visualization.")

# Display summary
if inference_metrics:
    total_inference_time = sum(m['duration_seconds'] for m in inference_metrics)
    total_inference_tokens = sum(m['token_counts'].get('total_tokens', 0) for m in inference_metrics)
    
    print(f"\nInference Summary:")
    print(f"  Total inference calls: {len(inference_metrics)}")
    print(f"  Total inference time: {total_inference_time:.2f} seconds")
    print(f"  Total tokens: {total_inference_tokens:,}")
    print(f"  Average time per call: {total_inference_time / len(inference_metrics):.2f} seconds")
    print(f"  Throughput: {total_inference_tokens / total_inference_time:.2f} tokens/second" if total_inference_time > 0 else "  Throughput: N/A")
# Out:
# Loaded 772 existing metrics from notebook 01
# Added 9 inference metrics
#
# Saving all metrics to: results/metrics.json
# ✅ All metrics saved successfully!
# You can now proceed to notebook 03 for reporting and visualization.
#
# Inference Summary:
#   Total inference calls: 9
#   Total inference time: 15.09 seconds
#   Total tokens: 5,401
#   Average time per call: 1.68 seconds
#   Throughput: 357.89 tokens/second
