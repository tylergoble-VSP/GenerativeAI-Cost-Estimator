# %% [markdown]
# # Notebook 02: Inference and Question Generation
#
# This notebook demonstrates:
# 1. Loading embedded chunks from the previous notebook
# 2. Asking user-defined questions about the document
# 3. Auto-generating questions from chunks
# 4. Tracking tokens and timing for all inference calls
# 5. Saving inference metrics for reporting
#
# ## Setup

# %%
# Import standard library modules
import json
import sys
from pathlib import Path

# Add the src directory to Python path
project_root = Path().resolve().parent
sys.path.insert(0, str(project_root))

# Import our custom modules
from src.config import Config
from src.pipeline import generate_questions, save_metrics
from src.ollama_client import generate
from src.timing_metrics import MetricsStore, TimingContext
from src.token_accounting import count_tokens, count_prompt_and_response

print("Modules imported successfully!")
# Out:
# Modules imported successfully!

# %% [markdown]
# ## Configuration and Load Previous Results

# %%
# Create configuration (same as notebook 01)
config = Config(
    embedding_model="embeddinggemma",
    generation_model="gemma3:1b",
    ollama_endpoint="http://localhost:11434"
)

# Load embedded chunks from previous notebook
chunks_path = config.get_chunks_path()
print(f"Loading chunks from: {chunks_path}")

with open(chunks_path, 'r') as f:
    embedded_chunks = json.load(f)

print(f"Loaded {len(embedded_chunks)} embedded chunks")

# Create metrics store for inference metrics
# We'll add to this as we make inference calls
inference_metrics_store = MetricsStore()
# Out:
# Loading chunks from: results/chunks.json
# Loaded 772 embedded chunks

# %% [markdown]
# ## User-Defined Questions
#
# Ask your own questions about the document. Each question will be sent to the model with relevant context from the chunks.

# %%
# Example user-defined questions
# You can modify these or add your own
user_questions = [
    "What is the main theme of this passage?",
    "What question does this passage make you ask yourself?",
    "What is the main charater of this passage?"
]

# Store all question-answer pairs
qa_pairs = []

# Process each user question
for idx, question in enumerate(user_questions):
    print(f"\n{'='*60}")
    print(f"Question {idx + 1}: {question}")
    print('='*60)
    
    # For simplicity, we'll use the first chunk as context
    # In a real RAG system, you'd use vector similarity to find the most relevant chunks
    context_chunk = embedded_chunks[0] if embedded_chunks else None
    
    if context_chunk:
        # Build prompt with context
        prompt = f"""Based on the following text, answer this question: {question}

Text:
{context_chunk['text']}

Answer:"""
        
        # Count prompt tokens
        prompt_tokens = count_tokens(prompt)
        
        # Time the inference call
        with TimingContext() as timer:
            # Call Ollama to generate answer
            response_text, metadata = generate(
                prompt,
                config.generation_model,
                config.ollama_endpoint
            )
        
        # Get duration
        duration = timer.duration
        
        # Count response tokens
        response_tokens = count_tokens(response_text)
        
        # Record metrics
        question_id = f"user_question_{idx}"
        inference_metrics_store.add_inference_metric(
            duration=duration,
            prompt_tokens=prompt_tokens,
            response_tokens=response_tokens,
            question_id=question_id,
            response_text=response_text
        )
        
        # Store Q&A pair
        qa_pairs.append({
            'question_id': question_id,
            'question': question,
            'answer': response_text,
            'chunk_id': context_chunk['chunk_id']
        })
        
        # Display results
        print(f"\nAnswer:")
        print(response_text)
        print(f"\nMetrics:")
        print(f"  Prompt tokens: {prompt_tokens}")
        print(f"  Response tokens: {response_tokens}")
        print(f"  Total tokens: {prompt_tokens + response_tokens}")
        print(f"  Duration: {duration:.2f} seconds")
        print(f"  Tokens/second: {(prompt_tokens + response_tokens) / duration:.2f}" if duration > 0 else "  Tokens/second: N/A")
    else:
        print("No chunks available for context")
# Out:
# ============================================================
# Question 1: What is the main theme of this passage?
# ============================================================
#
# Answer:
# The main theme of this passage is a complex exploration of obsession, the destructive nature of man, and the struggle between good and evil. It centers around the pursuit of a mythical whale and the protagonist’s increasingly consuming and ultimately destructive obsession. The text highlights themes of revenge, madness, and the dangers of unchecked desire, all interwoven with a sense of melancholy and a deep philosophical contemplation on the human condition. Essentially, it’s a story about a man consumed by his own thoughts and desires, leading to a potentially catastrophic outcome.
#
# Metrics:
#   Prompt tokens: 534
#   Response tokens: 108
#   Total tokens: 642
#   Duration: 0.79 seconds
#   Tokens/second: 812.22
#
# ============================================================
# Question 2: What question does this passage make you ask yourself?
# ============================================================
#
# Answer:
# What question does this passage make you ask yourself?
#
# The passage primarily focuses on the story’s setting and immediate context – the whaling expedition and the character Ahab. It asks questions like: “What is the purpose of this story? Why is it being published freely?” and “What is the significance of the details presented – the imagery of the ship, the food, and the events?” It also prompts reflection on the character of Ahab and his obsession.
#
# Metrics:
#   Prompt tokens: 535
#   Response tokens: 92
#   Total tokens: 627
#   Duration: 0.75 seconds
#   Tokens/second: 838.60
#
# ============================================================
# Question 3: What is the main charater of this passage?
# ============================================================
#
# Answer:
# Based on the text, the main character of this passage is **Herman Melville**. The text explicitly states he is the author and the title of the book. It also describes him as the “creator” of the story.
#
# Metrics:
#   Prompt tokens: 535
#   Response tokens: 47
#   Total tokens: 582
#   Duration: 0.43 seconds
#   Tokens/second: 1345.37

# %% [markdown]
# ## Auto-Generate Questions from Chunks
#
# Automatically generate questions from chunks. This is useful for creating a question-answer dataset or testing the system.

# %%
# Generate questions from a few sample chunks
# This demonstrates the auto-generation capability
num_chunks_to_process = max(3, len(embedded_chunks))  # Process first 3 chunks
questions_per_chunk = 2  # Generate 2 questions per chunk

print(f"Generating {questions_per_chunk} questions from {num_chunks_to_process} chunks...")
print("This may take a while.\n")

all_generated_questions = []

for i, chunk in enumerate(embedded_chunks[:num_chunks_to_process]):
    print(f"\n{'='*60}")
    print(f"Processing chunk {i+1}/{num_chunks_to_process}: {chunk['chunk_id']}")
    print('='*60)
    
    # Generate questions for this chunk
    questions = generate_questions(
        chunk,
        num_questions=questions_per_chunk,
        config=config,
        metrics_store=inference_metrics_store
    )
    
    all_generated_questions.extend(questions)
    
    # Display generated questions
    for q in questions:
        print(f"\nQuestion: {q['question_text']}")

print(f"\n\nTotal questions generated: {len(all_generated_questions)}")
# Out:
# Generating 2 questions from 772 chunks...
# This may take a while.
#
#
# ============================================================
# Processing chunk 1/772: chunk_0
# ============================================================
#
# Question: What is the release date of the eBook?
#
# Question: Where can users obtain the eBook?
#
# ============================================================
# Processing chunk 2/772: chunk_1
# ============================================================
#
# Question: What does Stubb do to Ahab?
#
# Question: What is the title of the first chapter?
#
# ============================================================
# Processing chunk 3/772: chunk_2
# ============================================================
#
# Question: What is the central focus of the text’s first eight chapters?
#
# Question: What is the significance of the “Pequod Meets The Rose-Bud” passage?
#
# ============================================================
# Processing chunk 4/772: chunk_3
# ============================================================
#
# Question: What is the text primarily about?
#
# Question: What does the late Usher suggest about the whale?
#
# ============================================================
# Processing chunk 5/772: chunk_4
# ============================================================
#
# Question: What is the meaning of “rolling” in the context of the text?
#
# Question: What is the primary purpose of the extracts provided?
#
# ============================================================
# Processing chunk 6/772: chunk_5
# ============================================================
#
# Question: What is the purpose of the extracts?
#
# Question: What is Leviathan?
#
# ============================================================
# Processing chunk 7/772: chunk_6
# ============================================================
#
# Question: What is the primary focus of the text’s narrative?
#
# Question: What does the text suggest about the whale’s value?
#
# ============================================================
# Processing chunk 8/772: chunk_7
# ============================================================
#
# Question: What does the sea-gudgeon do in the whale’s mouth?
#
# Question: What is the significance of the whale’s liver?
#
# ============================================================
# Processing chunk 9/772: chunk_8
# ============================================================
#
# Question: What is the subject of the text?
#
# Question: What does the text describe about the Leviathan?
#
# ============================================================
# Processing chunk 10/772: chunk_9
# ============================================================
#
# Question: What is the primary concern voiced about the whales’ actions?
#
# Question: What does the text suggest about the whales’ behavior?
#
# ============================================================
# Processing chunk 11/772: chunk_10
# ============================================================
#
# Question: What is Richard Strafford’s primary motivation for attempting to kill the sperm whale?
#
# Question: According to the text, how much more abundant were the whales in the southern seas compared to the north?
#
# ============================================================
# Processing chunk 12/772: chunk_11
# ============================================================
#
# Question: What was the nature of the “dead whale” discovered by the Asiatics?
#
# Question: What was the purpose of the fishermen’s provisions on their boats?
#
# ============================================================
# Processing chunk 13/772: chunk_12
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: What is the significance of the “blood” being thrown from the whale’s heart?
#
# ============================================================
# Processing chunk 14/772: chunk_13
# ============================================================
#
# Question: What is the primary focus of the text’s imagery?
#
# Question: According to the text, what is the significance of the “green pasture” mentioned by Tom?
#
# ============================================================
# Processing chunk 15/772: chunk_14
# ============================================================
#
# Question: What is Cooper’s Pilot referring to as “that fellow”?
#
# Question: What does the text describe as happening with the sperm whale?
#
# ============================================================
# Processing chunk 16/772: chunk_15
# ============================================================
#
# Question: What is the primary focus of the text regarding the Sperm Whale?
#
# Question: What does the text suggest about the Sperm Whale’s behavior?
#
# ============================================================
# Processing chunk 17/772: chunk_16
# ============================================================
#
# Question: What island was the whale-ship Globe located on?
#
# Question: What was the main focus of Mr. Webster’s speech in the U.S. Senate?
#
# ============================================================
# Processing chunk 18/772: chunk_17
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: What details does the text suggest about the whales?
#
# ============================================================
# Processing chunk 19/772: chunk_18
# ============================================================
#
# Question: What is Ishmael’s primary reason for sailing about the world?
#
# Question: What does Ishmael consider a “high time” to get to sea?
#
# ============================================================
# Processing chunk 20/772: chunk_19
# ============================================================
#
# Question: What is Cato’s substitute for a pistol and ball?
#
# Question: What is the setting of the text?
#
# ============================================================
# Processing chunk 21/772: chunk_20
# ============================================================
#
# Question: What is the primary contrast presented in the text regarding the landmen?
#
# Question: What does the artist’s landscape primarily focus on?
#
# ============================================================
# Processing chunk 22/772: chunk_21
# ============================================================
#
# Question: What is the central theme of the text?
#
# Question: What is the significance of the “mystical vibration” experienced by the poet?
#
# ============================================================
# Processing chunk 23/772: chunk_22
# ============================================================
#
# Question: What does the speaker mean by “a passenger”?
#
# Question: What is the speaker’s primary motivation for not going to sea as a passenger?
#
# ============================================================
# Processing chunk 24/772: chunk_23
# ============================================================
#
# Question: What is the primary reason the speaker feels the transition from schoolmaster to sailor is unpleasant?
#
# Question: What does the text suggest about the relationship between passengers and paying for services?
#
# ============================================================
# Processing chunk 25/772: chunk_24
# ============================================================
#
# Question: What is the central belief presented in the text regarding money?
#
# Question: What role does the text suggest the “invisible police officer of the Fates” plays?
#
# ============================================================
# Processing chunk 26/772: chunk_25
# ============================================================
#
# Question: What was the primary motivation for the whaling voyage as described in the text?
#
# Question: What specific details about the whale contribute to the feeling of unease in the text?
#
# ============================================================
# Processing chunk 27/772: chunk_26
# ============================================================
#
# Question: What is the setting of the text?
#
# Question: Where does the narrator initially go after arriving in New Bedford?
#
# ============================================================
# Processing chunk 28/772: chunk_27
# ============================================================
#
# Question: What was the primary purpose of the sloop’s voyage?
#
# Question: What did Ishmael bring with him in New Bedford?
#
# ============================================================
# Processing chunk 29/772: chunk_28
# ============================================================
#
# Question: What was the initial goal of the narrator?
#
# Question: What detail did the narrator notice in the dark building?
#
# ============================================================
# Processing chunk 30/772: chunk_29
# ============================================================
#
# Question: What is the significance of the swinging sign?
#
# Question: What details does the narrator find intriguing about the location?
#
# ============================================================
# Processing chunk 31/772: chunk_30
# ============================================================
#
# Question: What does the old writer believe are windows in the passage?
#
# Question: What does Lazarus seem to prefer to do in his current situation?
#
# ============================================================
# Processing chunk 32/772: chunk_31
# ============================================================
#
# Question: What is the primary reason the characters are going to the fiery pit?
#
# Question: What does the Spouter-Inn symbolize in the text?
#
# ============================================================
# Processing chunk 33/772: chunk_32
# ============================================================
#
# Question: What was the initial reaction of the narrator to the painting?
#
# Question: What does the image of the whale represent?
#
# ============================================================
# Processing chunk 34/772: chunk_33
# ============================================================
#
# Question: What type of weapons were originally contained in the mixed materials?
#
# Question: What is the significance of the “dark-looking den” in the room?
#
# ============================================================
# Processing chunk 35/772: chunk_34
# ============================================================
#
# Question: What is the landlord’s primary focus during the conversation?
#
# Question: What is the significance of the “harpooneer’s blanket” mentioned in the text?
#
# ============================================================
# Processing chunk 36/772: chunk_35
# ============================================================
#
# Question: What was the weather like at the meal?
#
# Question: What did the landlord say about the harpooneer?
#
# ============================================================
# Processing chunk 37/772: chunk_36
# ============================================================
#
# Question: What was the primary purpose of the mariners’ entry?
#
# Question: What did Jonah mix the mariners with?
#
# ============================================================
# Processing chunk 38/772: chunk_37
# ============================================================
#
# Question: What color were Bulkington’s teeth?
#
# Question: What was the primary reason for the harpooneer’s escape?
#
# ============================================================
# Processing chunk 39/772: chunk_38
# ============================================================
#
# Question: What was the harpooneer’s initial opinion of his linen or woollen attire?
#
# Question: What did the harpooneer say about the bench?
#
# ============================================================
# Processing chunk 40/772: chunk_39
# ============================================================
#
# Question: What was the initial problem with the first bench?
#
# Question: What did the narrator initially consider a possible solution to the situation?
#
# ============================================================
# Processing chunk 41/772: chunk_40
# ============================================================
#
# Question: What does the landlord’s chuckle signify?
#
# Question: What is the central conflict between the speaker and the landlord?
#
# ============================================================
# Processing chunk 42/772: chunk_41
# ============================================================
#
# Question: What is the nature of the connection between the parties involved?
#
# Question: What is the landlord’s stated liability for potential criminal prosecution?
#
# ============================================================
# Processing chunk 43/772: chunk_42
# ============================================================
#
# Question: What is the landlord’s primary concern regarding the harpooneer?
#
# Question: What event led to the landlord’s change of heart regarding the harpooneer?
#
# ============================================================
# Processing chunk 44/772: chunk_43
# ============================================================
#
# Question: What does Sal offer to the narrator?
#
# Question: What does the narrator do after Sal offers to lead the way?
#
# ============================================================
# Processing chunk 45/772: chunk_44
# ============================================================
#
# Question: What did the narrator initially do with the door mat?
#
# Question: What happened to the narrator after he ripped himself out of the door mat?
#
# ============================================================
# Processing chunk 46/772: chunk_45
# ============================================================
#
# Question: What does the narrator think the stranger is?
#
# Question: What does the narrator conclude about the stranger’s appearance?
#
# ============================================================
# Processing chunk 47/772: chunk_46
# ============================================================
#
# Question: What was the stranger doing with the New Zealand head?
#
# Question: What did the stranger do after he showed his chest and arms?
#
# ============================================================
# Processing chunk 48/772: chunk_47
# ============================================================
#
# Question: What was the writer’s initial reaction to the man?
#
# Question: What details were present in the man’s appearance that suggested he was from the Thirty Years’ War?
#
# ============================================================
# Processing chunk 49/772: chunk_48
# ============================================================
#
# Question: What was the purpose of the fire-place?
#
# Question: What did the man do with the shavings?
#
# ============================================================
# Processing chunk 50/772: chunk_49
# ============================================================
#
# Question: What was the initial reaction of the narrator to the cannibal’s behavior?
#
# Question: How does the narrator attempt to regain control of the situation after the cannibal’s initial actions?
#
# ============================================================
# Processing chunk 51/772: chunk_50
# ============================================================
#
# Question: What is Queequeg’s primary concern regarding the landlord?
#
# Question: How does the description of the counterpane contribute to the atmosphere of the text?
#
# ============================================================
# Processing chunk 52/772: chunk_51
# ============================================================
#
# Question: What was the character’s arm depicted as?
#
# Question: How did the character feel when they were cut off from their mother?
#
# ============================================================
# Processing chunk 53/772: chunk_52
# ============================================================
#
# Question: What was the small feeling the narrator was experiencing?
#
# Question: What did the narrator do after falling into a nightmare?
#
# ============================================================
# Processing chunk 54/772: chunk_53
# ============================================================
#
# Question: What specific sensation did the narrator experience during the night?
#
# Question: What action did the narrator take to attempt to wake Queequeg?
#
# ============================================================
# Processing chunk 55/772: chunk_54
# ============================================================
#
# Question: What caused the man to be restless and agitated?
#
# Question: What was the man’s reaction to the narrator’s presence?
#
# ============================================================
# Processing chunk 56/772: chunk_55
# ============================================================
#
# Question: What was Queequeg’s occupation?
#
# Question: What did Queequeg do with his boots?
#
# ============================================================
# Processing chunk 57/772: chunk_56
# ============================================================
#
# Question: What did Queequeg do to his face after washing himself?
#
# Question: What is the tone of the passage regarding the landlord?
#
# ============================================================
# Processing chunk 58/772: chunk_57
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: What details are mentioned about the young man’s cheek?
#
# ============================================================
# Processing chunk 59/772: chunk_58
# ============================================================
#
# Question: What is the author’s opinion of travel as a means of achieving a high social polish?
#
# Question: Describe the scene of the sea-dogs boarding whales.
#
# ============================================================
# Processing chunk 60/772: chunk_59
# ============================================================
#
# Question: What does the author mean by “coolly done”?
#
# Question: What is the significance of the text’s focus on whaling activity?
#
# ============================================================
# Processing chunk 61/772: chunk_60
# ============================================================
#
# Question: What is the primary motivation of the men traveling to the town?
#
# Question: What details are specifically mentioned about the character strutting in the corner?
#
# ============================================================
# Processing chunk 62/772: chunk_61
# ============================================================
#
# Question: What is the primary reason the town of New Bedford is considered the dearest place to live in?
#
# Question: What is the significance of the harpoons mentioned in the text?
#
# ============================================================
# Processing chunk 63/772: chunk_62
# ============================================================
#
# Question: What is the setting of the text?
#
# Question: What is the primary focus of the narrator’s first morning stroll?
#
# ============================================================
# Processing chunk 64/772: chunk_63
# ============================================================
#
# Question: Who was killed by a Sperm Whale in Japan?
#
# Question: What was placed by the surviving shipmates near the memorial?
#
# ============================================================
# Processing chunk 65/772: chunk_64
# ============================================================
#
# Question: What is the core of the text's concern regarding the dead?
#
# Question: What is the significance of the “whalemen” in the text?
#
# ============================================================
# Processing chunk 66/772: chunk_65
# ============================================================
#
# Question: What is the main theme of the text?
#
# Question: What does Father Mapple’s age suggest?
#
# ============================================================
# Processing chunk 67/772: chunk_66
# ============================================================
#
# Question: What was Father Mapple wearing?
#
# Question: What was the architect’s intention with the pulpit’s design?
#
# ============================================================
# Processing chunk 68/772: chunk_67
# ============================================================
#
# Question: What does the text suggest Father Mapple’s actions signify?
#
# Question: How does the text portray Father Mapple’s spiritual withdrawal?
#
# ============================================================
# Processing chunk 69/772: chunk_68
# ============================================================
#
# Question: What does the pulpit resemble?
#
# Question: What is the significance of the pulpit being “fashioned after a ship’s fiddle-headed beak”?
#
# ============================================================
# Processing chunk 70/772: chunk_69
# ============================================================
#
# Question: What is the tone of the text?
#
# Question: What is the purpose of the preacher’s actions?
#
# ============================================================
# Processing chunk 71/772: chunk_70
# ============================================================
#
# Question: What is the core lesson the book of Jonah teaches?
#
# Question: What does Jonah’s actions suggest about the nature of obedience and disobedience?
#
# ============================================================
# Processing chunk 72/772: chunk_71
# ============================================================
#
# Question: What was the primary reason Jonah sought to flee from God?
#
# Question: What details suggest Jonah is a fugitive?
#
# ============================================================
# Processing chunk 73/772: chunk_72
# ============================================================
#
# Question: What is the main subject of the passage?
#
# Question: What is Jonah’s reaction to the Captain’s question?
#
# ============================================================
# Processing chunk 74/772: chunk_73
# ============================================================
#
# Question: What does the Captain’s behavior reveal about his character?
#
# Question: What does the text suggest about Jonah’s state?
#
# ============================================================
# Processing chunk 75/772: chunk_74
# ============================================================
#
# Question: What is Jonah feeling in the contracted hole?
#
# Question: What does the lamp’s oscillation do?
#
# ============================================================
# Processing chunk 76/772: chunk_75
# ============================================================
#
# Question: What was the first of recorded smugglers?
#
# Question: What event triggered Jonah’s awakening?
#
# ============================================================
# Processing chunk 77/772: chunk_76
# ============================================================
#
# Question: What is the primary focus of the narrative?
#
# Question: What is the significance of Jonah’s confession?
#
# ============================================================
# Processing chunk 78/772: chunk_77
# ============================================================
#
# Question: What is the significance of Jonah being “not yet supplicating” to God?
#
# Question: What was the nature of the tempest affecting the ship?
#
# ============================================================
# Processing chunk 79/772: chunk_78
# ============================================================
#
# Question: What does the preacher’s description of the storm suggest about the situation?
#
# Question: What is the significance of the preacher’s final words?
#
# ============================================================
# Processing chunk 80/772: chunk_79
# ============================================================
#
# Question: What was Jonah’s initial mission?
#
# Question: Where did Jonah flee to after his mission?
#
# ============================================================
# Processing chunk 81/772: chunk_80
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: What does Paul’s proclamation suggest about the nature of delight?
#
# ============================================================
# Processing chunk 82/772: chunk_81
# ============================================================
#
# Question: What is the speaker’s state of mind regarding eternity?
#
# Question: What is the speaker doing with the idol of Queequeg?
#
# ============================================================
# Processing chunk 83/772: chunk_82
# ============================================================
#
# Question: What was the Pagan’s appearance described as?
#
# Question: How did the narrator describe Queequeg’s head?
#
# ============================================================
# Processing chunk 84/772: chunk_83
# ============================================================
#
# Question: What was the man’s initial reaction to being lost and far from home?
#
# Question: What does the text suggest about the man’s state of mind?
#
# ============================================================
# Processing chunk 85/772: chunk_84
# ============================================================
#
# Question: What did the little boy notice initially?
#
# Question: What did the narrator do to engage the boy’s interest?
#
# ============================================================
# Processing chunk 86/772: chunk_85
# ============================================================
#
# Question: What was the initial action the narrator planned to take?
#
# Question: What did the narrator do after the narrator silenced her?
#
# ============================================================
# Processing chunk 87/772: chunk_86
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: Describe the scene depicted in the first paragraph.
#
# ============================================================
# Processing chunk 88/772: chunk_87
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: What is the speaker’s overall attitude towards the scene?
#
# ============================================================
# Processing chunk 89/772: chunk_88
# ============================================================
#
# Question: What island was Queequeg native to?
#
# Question: What was Queequeg’s initial ambition when he left his father’s bay?
#
# ============================================================
# Processing chunk 90/772: chunk_89
# ============================================================
#
# Question: What did the man paddle off to?
#
# Question: What did Queequeg do when the ship passed by?
#
# ============================================================
# Processing chunk 91/772: chunk_90
# ============================================================
#
# Question: What was the initial plan of Queequeg after arriving in Nantucket?
#
# Question: What was the purpose of the harpooneer and the individual’s intentions regarding whaling?
#
# ============================================================
# Processing chunk 92/772: chunk_91
# ============================================================
#
# Question: What was Queequeg’s profession besides being a harpooneer?
#
# Question: What did the people stare at as the narrator and his companion traveled?
#
# ============================================================
# Processing chunk 93/772: chunk_92
# ============================================================
#
# Question: What is Queequeg’s primary reason for preferring his own harpoon?
#
# Question: How does Queequeg describe the first wheelbarrow he saw?
#
# ============================================================
# Processing chunk 94/772: chunk_93
# ============================================================
#
# Question: What is the Captain’s primary focus when he’s positioned over the punchbowl?
#
# Question: What does Queequeg observe while looking upwards at the Giver of feasts?
#
# ============================================================
# Processing chunk 95/772: chunk_94
# ============================================================
#
# Question: What is the overall mood conveyed in the text?
#
# Question: How does the text describe the atmosphere surrounding the voyage?
#
# ============================================================
# Processing chunk 96/772: chunk_95
# ============================================================
#
# Question: What caused the bumpkin to be considered to have “hour of doom”?
#
# Question: What did the Captain do to the bumpkin?
#
# ============================================================
# Processing chunk 97/772: chunk_96
# ============================================================
#
# Question: What happened to the poor fellow who was swept overboard?
#
# Question: What did Queequeg do to secure the boom?
#
# ============================================================
# Processing chunk 98/772: chunk_97
# ============================================================
#
# Question: What did the captain beg Queequeg to do?
#
# Question: What did Queequeg do after asking for water?
#
# ============================================================
# Processing chunk 99/772: chunk_98
# ============================================================
#
# Question: What specific items did the Nantucketers import from Canada?
#
# Question: What significance does the story of the Indian’s disappearance have for the Nantucketers?
#
# ============================================================
# Processing chunk 100/772: chunk_99
# ============================================================
#
# Question: What did the Nantucketers do in the sand initially?
#
# Question: How did the Nantucketers expand their exploration?
#
# ============================================================
# Processing chunk 101/772: chunk_100
# ============================================================
#
# Question: What is the significance of the “Noah’s flood” mentioned in the text?
#
# Question: What does Queequeg suggest about the location of the yellow warehouse?
#
# ============================================================
# Processing chunk 102/772: chunk_101
# ============================================================
#
# Question: What is the significance of the two enormous wooden pots painted black?
#
# Question: What is the overall atmosphere or feeling conveyed in the passage regarding the setting?
#
# ============================================================
# Processing chunk 103/772: chunk_102
# ============================================================
#
# Question: What did Mrs. Hussey initially want to do with I?
#
# Question: What did the chowder reveal about Mrs. Hussey’s intentions?
#
# ============================================================
# Processing chunk 104/772: chunk_103
# ============================================================
#
# Question: What prompted Queequeg to experiment with the chowder?
#
# Question: What is the significance of the clam-shell paving in the area?
#
# ============================================================
# Processing chunk 105/772: chunk_104
# ============================================================
#
# Question: What was the Lady’s demand to Queequeg?
#
# Question: What did Queequeg tell Ishmael about the ship selection?
#
# ============================================================
# Processing chunk 106/772: chunk_105
# ============================================================
#
# Question: What was Queequeg’s primary goal in proposing a specific plan?
#
# Question: What did Ishmael feel about Queequeg’s plan?
#
# ============================================================
# Processing chunk 107/772: chunk_106
# ============================================================
#
# Question: What was the initial reaction of the narrator to Queequeg’s behavior?
#
# Question: What did the narrator do after leaving Queequeg in the bedroom?
#
# ============================================================
# Processing chunk 108/772: chunk_107
# ============================================================
#
# Question: What is the description of the old ship’s hull?
#
# Question: What was the primary focus of the old Captain Peleg’s work on the ship?
#
# ============================================================
# Processing chunk 109/772: chunk_108
# ============================================================
#
# Question: What is the primary focus of the text describing the tiller?
#
# Question: What is the significance of the conical shape of the wigwam?
#
# ============================================================
# Processing chunk 110/772: chunk_109
# ============================================================
#
# Question: What is the primary focus of the elderly man’s appearance?
#
# Question: What does the eye-wrinkles in the man’s eyes signify?
#
# ============================================================
# Processing chunk 111/772: chunk_110
# ============================================================
#
# Question: What is the seaman’s apparent suspicion regarding his intentions?
#
# Question: What does the seaman ultimately seek to understand regarding whaling?
#
# ============================================================
# Processing chunk 112/772: chunk_111
# ============================================================
#
# Question: What is the significance of the “lost by a whale” detail?
#
# Question: What does the speaker suggest about the young man’s character?
#
# ============================================================
# Processing chunk 113/772: chunk_112
# ============================================================
#
# Question: What is Captain Peleg’s primary goal in the request?
#
# Question: What does the weather bow indicate?
#
# ============================================================
# Processing chunk 114/772: chunk_113
# ============================================================
#
# Question: What is the primary connection between Captain Bildad and Captain Peleg?
#
# Question: What peculiar characteristic does the group of Quakers possess?
#
# ============================================================
# Processing chunk 115/772: chunk_114
# ============================================================
#
# Question: What is the central theme of the text?
#
# Question: What does the text suggest about Captain Bildad’s nature?
#
# ============================================================
# Processing chunk 116/772: chunk_115
# ============================================================
#
# Question: What was Bildad’s profession before his retirement?
#
# Question: What did the crew on the Categut whaleman say about Bildad?
#
# ============================================================
# Processing chunk 117/772: chunk_116
# ============================================================
#
# Question: What was Bildad’s primary characteristic, according to the text?
#
# Question: What does Bildad’s posture suggest about his character?
#
# ============================================================
# Processing chunk 118/772: chunk_117
# ============================================================
#
# Question: What is Bildad’s primary concern at the beginning of the passage?
#
# Question: What is the significance of the ‘lays’ in the whaling business as described?
#
# ============================================================
# Processing chunk 119/772: chunk_118
# ============================================================
#
# Question: What was the initial thought about the 275th laying?
#
# Question: How did Bildad’s interest in the Pequod’s affairs influence the decision regarding the seven hundred and seventy-seventh lay?
#
# ============================================================
# Processing chunk 120/772: chunk_119
# ============================================================
#
# Question: What is Bildad’s primary focus during the discussion?
#
# Question: What does Peleg believe Bildad will do with the seven hundred and seventy-seventh?
#
# ============================================================
# Processing chunk 121/772: chunk_120
# ============================================================
#
# Question: What is Bildad’s main concern regarding the seven hundred and seventy-seventh lay?
#
# Question: How does Peleg react to Bildad’s words regarding the seven hundred and seventy-seventh?
#
# ============================================================
# Processing chunk 122/772: chunk_121
# ============================================================
#
# Question: What is Bildad’s reaction to Peleg’s outburst?
#
# Question: What does Bildad want to know about Ishmael?
#
# ============================================================
# Processing chunk 123/772: chunk_122
# ============================================================
#
# Question: What is Bildad’s primary concern regarding the man he is to sail with?
#
# Question: What does the text suggest about Captain Ahab’s current state of mind?
#
# ============================================================
# Processing chunk 124/772: chunk_123
# ============================================================
#
# Question: What is the significance of Ahab’s “clever, ignorant whim” as described by Peleg?
#
# Question: What does Tistig’s prophecy suggest about Ahab’s personality?
#
# ============================================================
# Processing chunk 125/772: chunk_124
# ============================================================
#
# Question: What caused Captain Ahab’s moodiness and savage behavior?
#
# Question: What is the significance of the sweet girl and child of Captain Ahab?
#
# ============================================================
# Processing chunk 126/772: chunk_125
# ============================================================
#
# Question: What is Ahab’s primary focus at the beginning of the passage?
#
# Question: What does Ahab value regarding religious obligations?
#
# ============================================================
# Processing chunk 127/772: chunk_126
# ============================================================
#
# Question: What is the main reason for I’s alarm?
#
# Question: What detail does I notice in the room that suggests Queequeg is inside?
#
# ============================================================
# Processing chunk 128/772: chunk_127
# ============================================================
#
# Question: What was the primary reason for the man’s frantic activity?
#
# Question: What did Mrs. Hussey do to restrain the man?
#
# ============================================================
# Processing chunk 129/772: chunk_128
# ============================================================
#
# Question: What is the significance of “avast there!”?
#
# Question: What action does the landlady take after she catches the man?
#
# ============================================================
# Processing chunk 130/772: chunk_129
# ============================================================
#
# Question: What does Hussey believe about Queequeg’s state?
#
# Question: What does the narrator’s reaction to Queequeg suggest?
#
# ============================================================
# Processing chunk 131/772: chunk_130
# ============================================================
#
# Question: What is the primary source of the narrator’s despair?
#
# Question: What action does the narrator take after dropping off at last?
#
# ============================================================
# Processing chunk 132/772: chunk_131
# ============================================================
#
# Question: What does the author suggest is happening when a man’s religion becomes frantic?
#
# Question: What does the author do with Queequeg?
#
# ============================================================
# Processing chunk 133/772: chunk_132
# ============================================================
#
# Question: What battle was gained, and how many enemies were killed?
#
# Question: What did Queequeg do with the slain enemy after the battle?
#
# ============================================================
# Processing chunk 134/772: chunk_133
# ============================================================
#
# Question: What was Queequeg’s hearty breakfast?
#
# Question: What did Captain Peleg demand of Queequeg?
#
# ============================================================
# Processing chunk 135/772: chunk_134
# ============================================================
#
# Question: How long has Philistine been a member of Deacon Deuteronomy’s meeting?
#
# Question: What is the meaning of “splice hands”?
#
# ============================================================
# Processing chunk 136/772: chunk_135
# ============================================================
#
# Question: What was the harpoon the anchor man was holding?
#
# Question: What did Queequeg do after striking the tar spot?
#
# ============================================================
# Processing chunk 137/772: chunk_136
# ============================================================
#
# Question: What is the significance of the tattoo on Queequeg’s arm?
#
# Question: What does Bildad do after taking the tracts from Queequeg?
#
# ============================================================
# Processing chunk 138/772: chunk_137
# ============================================================
#
# Question: What did Peleg say about pious harpooneers?
#
# Question: What was Bildad focused on when he was observing the sailmakers?
#
# ============================================================
# Processing chunk 139/772: chunk_138
# ============================================================
#
# Question: What was Captain Ahab thinking about?
#
# Question: What was the stranger doing while observing the sailmakers?
#
# ============================================================
# Processing chunk 140/772: chunk_139
# ============================================================
#
# Question: What does the stranger’s nervous emphasis on the word “he” suggest?
#
# Question: What is the stranger’s primary concern regarding Captain Ahab?
#
# ============================================================
# Processing chunk 141/772: chunk_140
# ============================================================
#
# Question: What specific events are described as “nothing about his losing his leg last voyage”?
#
# Question: What does the beggar-like stranger say about Captain Ahab’s loss of his leg?
#
# ============================================================
# Processing chunk 142/772: chunk_141
# ============================================================
#
# Question: What does the speaker say about the “ineffable heavens” blessing?
#
# Question: What is the speaker’s assessment of Elijah’s character?
#
# ============================================================
# Processing chunk 143/772: chunk_142
# ============================================================
#
# Question: What was the primary reason the narrator was anxious about the stranger?
#
# Question: How did the narrator resolve to satisfy himself whether the stranger was dogging them?
#
# ============================================================
# Processing chunk 144/772: chunk_143
# ============================================================
#
# Question: What was the primary reason for the ship’s company to ensure their chests were on board?
#
# Question: What was the main consequence of the ship’s delay in sailing?
#
# ============================================================
# Processing chunk 145/772: chunk_144
# ============================================================
#
# Question: What was the primary reason for the continual fetching and carrying on board the Pequod?
#
# Question: What was Captain Charity’s nickname, and what did it signify?
#
# ============================================================
# Processing chunk 146/772: chunk_145
# ============================================================
#
# Question: What was Peleg roaring at during his “roaring”?
#
# Question: How did Peleg and Bildad manage to attend to everything necessary for the voyage?
#
# ============================================================
# Processing chunk 147/772: chunk_146
# ============================================================
#
# Question: What was the primary reason the sailors were running ahead?
#
# Question: What did Elijah do to assert his presence and observation?
#
# ============================================================
# Processing chunk 148/772: chunk_147
# ============================================================
#
# Question: What is the main reason the speaker is in a state of wonderment?
#
# Question: What detail about the sleeper’s appearance does the speaker observe?
#
# ============================================================
# Processing chunk 149/772: chunk_148
# ============================================================
#
# Question: What was Queequeg’s country way?
#
# Question: What did Queequeg offer to the sleeper?
#
# ============================================================
# Processing chunk 150/772: chunk_149
# ============================================================
#
# Question: What was the initial state of the vapor filling the contracted hole?
#
# Question: What was the man’s apparent state of being when he began to breathe?
#
# ============================================================
# Processing chunk 151/772: chunk_150
# ============================================================
#
# Question: What was Captain Bildad doing with Captain Ahab?
#
# Question: What was the primary reason Captain Peleg was commanding?
#
# ============================================================
# Processing chunk 152/772: chunk_151
# ============================================================
#
# Question: What was the immediate action the crew took upon receiving the command “Man the capstan!”?
#
# Question: What was Bildad’s alleged role in the port?
#
# ============================================================
# Processing chunk 153/772: chunk_152
# ============================================================
#
# Question: What is the main theme of the passage?
#
# Question: What does Bildad do throughout the passage?
#
# ============================================================
# Processing chunk 154/772: chunk_153
# ============================================================
#
# Question: What was the primary reason the pilots were no longer needed?
#
# Question: How did Peleg react to the situation of being left behind?
#
# ============================================================
# Processing chunk 155/772: chunk_154
# ============================================================
#
# Question: What is the main purpose of the speech?
#
# Question: What is the significance of the “hot supper”?
#
# ============================================================
# Processing chunk 156/772: chunk_155
# ============================================================
#
# Question: What is the setting of the text?
#
# Question: What is Bulkington’s apparent state of mind?
#
# ============================================================
# Processing chunk 157/772: chunk_156
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: According to the text, what is the significance of the “S.W.F.” on whaling cards?
#
# ============================================================
# Processing chunk 158/772: chunk_157
# ============================================================
#
# Question: What is the primary criticism of the whaling practice described in the text?
#
# Question: What is the significance of the Dutch admirals of whaling fleets?
#
# ============================================================
# Processing chunk 159/772: chunk_158
# ============================================================
#
# Question: Why did the Dutch in De Witt’s time have admirals of their whaling fleets?
#
# Question: Why did Louis XVI. of France fit out whaling ships from Dunkirk, and invite Nantucket families?
#
# ============================================================
# Processing chunk 160/772: chunk_159
# ============================================================
#
# Question: What was the significance of the “savages” being ridden by American and European men-of-war?
#
# Question: According to the text, what was the primary purpose of the whale-ship?
#
# ============================================================
# Processing chunk 161/772: chunk_160
# ============================================================
#
# Question: What is the whale-ship’s role in the colony’s success?
#
# Question: Who is credited with writing the first account of the Leviathan?
#
# ============================================================
# Processing chunk 162/772: chunk_161
# ...
# ============================================================
#
# Question: What was the nature of the crew that Stubb and Flask were comprised of?
#
# Question: What does the text suggest about Ahab’s state of mind at the beginning of the chapter?
#
# ============================================================
# Processing chunk 260/772: chunk_259
# ============================================================
#
# Question: What specific aspect of the whale’s whiteness disturbed the speaker?
#
# Question: What is the speaker’s primary motivation for attempting to explain themselves?
#
# ============================================================
# Processing chunk 261/772: chunk_260
# ============================================================
#
# Question: What does the text suggest about the importance of whiteness in the world?
#
# Question: Which of the listed examples of whiteness is most significant in the text’s description of a sacred ritual?
#
# ============================================================
# Processing chunk 262/772: chunk_261
# ============================================================
#
# Question: What is the primary reason for the prominence of whiteness in various cultures?
#
# Question: Which historical figure notably displayed the white color in a prominent position?
#
# ============================================================
# Processing chunk 263/772: chunk_262
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: How does the text characterize the white color?
#
# ============================================================
# Processing chunk 264/772: chunk_263
# ============================================================
#
# Question: What is the significance of the white shark’s “white gliding ghostliness” as described in the text?
#
# Question: What does the French call the white shark?
#
# ============================================================
# Processing chunk 265/772: chunk_264
# ============================================================
#
# Question: What was the name of the bird the sailor described?
#
# Question: What is the significance of the “seaman’s name” for albatross?
#
# ============================================================
# Processing chunk 266/772: chunk_265
# ============================================================
#
# Question: What is the White Steed’s primary attribute?
#
# Question: What is the significance of the Albino man’s whiteness?
#
# ============================================================
# Processing chunk 267/772: chunk_266
# ============================================================
#
# Question: What is the key difference between the Albino’s appearance and the ugliest abortion?
#
# Question: How does the white snow influence the meaning of Froissart’s passage?
#
# ============================================================
# Processing chunk 268/772: chunk_267
# ============================================================
#
# Question: What is the significance of the “peculiar apparition” to the soul?
#
# Question: How can mortal man account for the phenomenon described?
#
# ============================================================
# Processing chunk 269/772: chunk_268
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: What is the significance of the “white veil” mentioned in the text?
#
# ============================================================
# Processing chunk 270/772: chunk_269
# ============================================================
#
# Question: What is the mariner’s reaction to the whiteness in the example?
#
# Question: What does the native Indian experience when confronted with the whiteness?
#
# ============================================================
# Processing chunk 271/772: chunk_270
# ============================================================
#
# Question: Why does the colt start snorting and pawing the ground?
#
# Question: What does the colt smell that evokes the memory of past perils?
#
# ============================================================
# Processing chunk 272/772: chunk_271
# ============================================================
#
# Question: What is the metaphor comparing the buffalo robe to?
#
# Question: What does the text suggest about the significance of white?
#
# ============================================================
# Processing chunk 273/772: chunk_272
# ============================================================
#
# Question: What is the central idea presented in the text?
#
# Question: What does the text suggest about the “palsied universe”?
#
# ============================================================
# Processing chunk 274/772: chunk_273
# ============================================================
#
# Question: What is the atmosphere described as in the “hallowed precincts of the quarter-deck”?
#
# Question: What is the main subject of the conversation between Archy and Cabaco?
#
# ============================================================
# Processing chunk 275/772: chunk_274
# ============================================================
#
# Question: What was the activity Captain Ahab was engaged in after the squall?
#
# Question: What did Ahab do with the charts in his cabin?
#
# ============================================================
# Processing chunk 276/772: chunk_275
# ============================================================
#
# Question: What is Ahab’s method of calculating the sperm whale’s food?
#
# Question: What is the significance of the sperm whale’s migratory charts?
#
# ============================================================
# Processing chunk 277/772: chunk_276
# ============================================================
#
# Question: What does the text describe as the division of the ocean into districts?
#
# Question: What does the text suggest about the way whales navigate?
#
# ============================================================
# Processing chunk 278/772: chunk_277
# ============================================================
#
# Question: What was Ahab’s initial goal in relation to Moby Dick?
#
# Question: What does the phrase “Season-on-the-Line” refer to?
#
# ============================================================
# Processing chunk 279/772: chunk_278
# ============================================================
#
# Question: What was the primary reason for the Pequod’s sailing at the beginning of the Season-on-the-Line?
#
# Question: What was Ahab’s plan regarding the Pequod’s voyage?
#
# ============================================================
# Processing chunk 280/772: chunk_279
# ============================================================
#
# Question: What is the significance of the “white-bearded Mufti” in the context of Moby Dick?
#
# Question: What is the main focus of Ahab’s thoughts and actions as he is sailing?
#
# ============================================================
# Processing chunk 281/772: chunk_280
# ============================================================
#
# Question: What does Ahab endure while he sleeps?
#
# Question: What is the primary cause of Ahab’s behavior in his sleep?
#
# ============================================================
# Processing chunk 282/772: chunk_281
# ============================================================
#
# Question: What is the ‘eternal, living principle or soul’ in Ahab’s case?
#
# Question: What does the text suggest about Ahab’s state when he yields up his thoughts?
#
# ============================================================
# Processing chunk 283/772: chunk_282
# ============================================================
#
# Question: What specific type of whaling experience did the narrator detail?
#
# Question: What detail in the second instance does the narrator highlight?
#
# ============================================================
# Processing chunk 284/772: chunk_283
# ============================================================
#
# Question: What is the primary reason for the whale’s marked state?
#
# Question: What is the significance of the whale’s markings to the Sperm Whale Fishery?
#
# ============================================================
# Processing chunk 285/772: chunk_284
# ============================================================
#
# Question: What is the primary purpose of the whales' salutations?
#
# Question: What is the significance of the whales’ reputations?
#
# ============================================================
# Processing chunk 286/772: chunk_285
# ============================================================
#
# Question: What is the author’s primary concern regarding the Fishery?
#
# Question: What is the significance of the ‘irregular’ mail between New Guinea and the rest of the world?
#
# ============================================================
# Processing chunk 287/772: chunk_286
# ============================================================
#
# Question: What was the significance of the whale’s actions in the Essex incident?
#
# Question: What is the primary focus of the text?
#
# ============================================================
# Processing chunk 288/772: chunk_287
# ============================================================
#
# Question: What was Captain Pollard’s last return home?
#
# Question: What did Chace report about the Essex’s operations?
#
# ============================================================
# Processing chunk 289/772: chunk_288
# ============================================================
#
# Question: What was the writer’s primary focus during the described period?
#
# Question: What specific event did the Commodore avoid while sailing Valparaiso?
#
# ============================================================
# Processing chunk 290/772: chunk_289
# ============================================================
#
# Question: What was the purpose of the text?
#
# Question: What is the Captain D’Wolf’s profession?
#
# ============================================================
# Processing chunk 291/772: chunk_290
# ============================================================
#
# Question: What type of ship was the text describing?
#
# Question: What was the ship’s origin?
#
# ============================================================
# Processing chunk 292/772: chunk_291
# ============================================================
#
# Question: What did the authors suggest was the initial cause of the shock?
#
# Question: What does Lionel hypothesize to be the cause of the shock?
#
# ============================================================
# Processing chunk 293/772: chunk_292
# ============================================================
#
# Question: What is the primary characteristic observed of the sperm whale in the text?
#
# Question: According to the text, what is the significance of the sea-monster’s capture?
#
# ============================================================
# Processing chunk 294/772: chunk_293
# ============================================================
#
# Question: What is the author’s initial belief about the sperm whale’s presence in the Mediterranean?
#
# Question: According to the text, what is the likely food source of the sperm whale?
#
# ============================================================
# Processing chunk 295/772: chunk_294
# ============================================================
#
# Question: What was Ahab’s primary motivation throughout the text?
#
# ============================================================
# Processing chunk 296/772: chunk_295
# ============================================================
#
# Question: What is Ahab’s primary concern regarding the hunt?
#
# Question: What is Ahab’s assessment of humanity’s nature?
#
# ============================================================
# Processing chunk 297/772: chunk_296
# ============================================================
#
# Question: What was the primary reason for Ahab’s cautious approach to the voyage?
#
# Question: What was Ahab’s primary concern regarding the Pequod’s voyage?
#
# ============================================================
# Processing chunk 298/772: chunk_297
# ============================================================
#
# Question: What was the activity Queequeg and the narrator were engaged in?
#
# Question: What does the text suggest about the atmosphere of the scene?
#
# ============================================================
# Processing chunk 299/772: chunk_298
# ============================================================
#
# Question: What is the primary purpose of the weaver’s shuttle?
#
# Question: What does the text suggest about the nature of chance?
#
# ============================================================
# Processing chunk 300/772: chunk_299
# ============================================================
#
# Question: What was Tashtego’s role in the scene?
#
# Question: What did the Sperm Whale cry about?
#
# ============================================================
# Processing chunk 301/772: chunk_300
# ============================================================
#
# Question: What was the primary activity of the sailors at the fore and mizzen?
#
# Question: What was the description of the man standing by the bow of the ship?
#
# ============================================================
# Processing chunk 302/772: chunk_301
# ============================================================
#
# Question: What was the primary focus of Ahab’s voice?
#
# Question: What action did the sailors take after Ahab’s command?
#
# ============================================================
# Processing chunk 303/772: chunk_302
# ============================================================
#
# Question: What is Stubb’s primary goal in his speech to his crew?
#
# Question: What does Stubb’s exordium primarily serve to accomplish?
#
# ============================================================
# Processing chunk 304/772: chunk_303
# ============================================================
#
# Question: What was Stubb’s primary method of interacting with his crew?
#
# Question: What effect did Stubb’s easy and indolent demeanor have on the crew?
#
# ============================================================
# Processing chunk 305/772: chunk_304
# ============================================================
#
# Question: What is the primary focus of Mr. Stubb’s command?
#
# Question: What is the significance of the “White Whale’s” presence?
#
# ============================================================
# Processing chunk 306/772: chunk_305
# ============================================================
#
# Question: What is the significance of Ahab’s behavior?
#
# Question: How does Starbuck’s action reflect Ahab’s state of mind?
#
# ============================================================
# Processing chunk 307/772: chunk_306
# ============================================================
#
# Question: What was the primary activity Flask was engaged in?
#
# Question: What did Daggoo want Flask to do?
#
# ============================================================
# Processing chunk 308/772: chunk_307
# ============================================================
#
# Question: What is the primary focus of the text?
#
# Question: What does Stubb do with the pipe?
#
# ============================================================
# Processing chunk 309/772: chunk_308
# ============================================================
#
# Question: What was the man loading?
#
# Question: What did the man do immediately after loading?
#
# ============================================================
# Processing chunk 310/772: chunk_309
# ============================================================
#
# Question: What did Stubb do with the plantation after he pulled the crew?
#
# Question: What is the primary focus of Ahab’s actions in the text?
#
# ============================================================
# Processing chunk 311/772: chunk_310
# ============================================================
#
# Question: What is the “whale” that Flask alludes to?
#
# Question: What is the punishment for violating the rule regarding the oarsmen?
#
# ============================================================
# Processing chunk 312/772: chunk_311
# ============================================================

# %% [markdown]
# ## Save Inference Metrics
#
# Save all inference metrics to disk so they can be used in the reporting notebook.

# %%
# Load existing metrics from notebook 01 (if they exist)
# Then merge with inference metrics
import json

metrics_path = config.get_metrics_path()
all_metrics = []

# Load existing metrics
if metrics_path.exists():
    with open(metrics_path, 'r') as f:
        all_metrics = json.load(f)
    print(f"Loaded {len(all_metrics)} existing metrics from notebook 01")

# Add inference metrics
inference_metrics = inference_metrics_store.metrics
all_metrics.extend(inference_metrics)
print(f"Added {len(inference_metrics)} inference metrics")

# Save combined metrics
print(f"\nSaving all metrics to: {metrics_path}")
with open(metrics_path, 'w') as f:
    json.dump(all_metrics, f, indent=2)

print("✅ All metrics saved successfully!")
print("You can now proceed to notebook 03 for reporting and visualization.")

# Display summary
if inference_metrics:
    total_inference_time = sum(m['duration_seconds'] for m in inference_metrics)
    total_inference_tokens = sum(m['token_counts'].get('total_tokens', 0) for m in inference_metrics)
    
    print(f"\nInference Summary:")
    print(f"  Total inference calls: {len(inference_metrics)}")
    print(f"  Total inference time: {total_inference_time:.2f} seconds")
    print(f"  Total tokens: {total_inference_tokens:,}")
    print(f"  Average time per call: {total_inference_time / len(inference_metrics):.2f} seconds")
    print(f"  Throughput: {total_inference_tokens / total_inference_time:.2f} tokens/second" if total_inference_time > 0 else "  Throughput: N/A")
# Out:
# Loaded 772 existing metrics from notebook 01
# Added 1541 inference metrics
#
# Saving all metrics to: results/metrics.json
# ✅ All metrics saved successfully!
# You can now proceed to notebook 03 for reporting and visualization.
#
# Inference Summary:
#   Total inference calls: 1541
#   Total inference time: 300.39 seconds
#   Total tokens: 815,983
#   Average time per call: 0.19 seconds
#   Throughput: 2716.44 tokens/second
